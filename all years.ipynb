# %% [markdown]
# # Libraries

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd
import re
import time

# %% [markdown]
# # Functions to extract matches and players ' information

# %%
def extract_matches_df(url):
    try:
        # Initialize Selenium
        chrome_service = ChromeService("C:/Users/ALESSANDRO/Downloads/chromedriver.exe")
        chrome_service.start()
        chrome_options = Options()
        chrome_options.add_argument("--headless")
        driver = webdriver.Chrome(service=chrome_service, options=chrome_options)
        # Navigate to the webpage
        driver.get(url)

        # Wait for the page to be loaded
        loaded = False
        while not loaded:
            try:
                main_element = driver.find_element(By.CLASS_NAME, "main")
                loaded = True
                print("Loaded!")
            except:
                time.sleep(1)
                print("waiting...")
        # ---------------------------------------------------------------------------------------------

        # Find the div element with class "main"
        main_element = driver.find_element(By.CLASS_NAME, "main")

        # Include the component_title_text in the stage variable
        component_title_element = main_element.find_element(By.CLASS_NAME, "component-title")
        stage = component_title_element.text.strip()

        # ---------------------------------------------------------------------------------------------

        # Now, let's find the div element with class "tie" within the main element
        tie_element = main_element.find_element(By.CLASS_NAME, "details")

        # Find all sub div elements within the "tie" element
        sub_div_elements = tie_element.find_elements(By.TAG_NAME, "div")

        # Initialize variables to store data
        column_data = {}

        for sub_div_element in sub_div_elements:
            sub_div_text = sub_div_element.text.strip()
            if ":" in sub_div_text:
                column_name, column_value = sub_div_text.split(":", 1)
                column_data[column_name] = [column_value]

        # Create a DataFrame from the collected data
        df = pd.DataFrame(column_data)

        # Add the "Stage" column with the component_title_text
        df["Stage"] = stage

        # ---------------------------------------------------------------------------------------------

        # Find the div element with class "rubber-header"
        rubber_header_elements = main_element.find_elements(By.CLASS_NAME, "rubber-header")
        match_num = []
        match_status = []

        for rubber_header_element in rubber_header_elements:

            # Extract "match" and "match status" from the span elements
            spans = rubber_header_element.find_elements(By.TAG_NAME, "span")

            if len(spans) >= 2:
                match_num.append(spans[0].text.strip())
                match_status.append(spans[1].text.strip())
            #       match = span_element.text.strip()

        # ---------------------------------------------------------------------------------------------
        # Now, let's find the div element with class "rubber-body" within the main element
        rubber_body_elements = main_element.find_elements(By.CLASS_NAME, "rubber-body")
        tables_data = []

        match_idx = -1
        for rubber_body_element in rubber_body_elements:
            match_idx += 1

            # Find all tables with class "dc" within the rubber-body
            table_elements = rubber_body_element.find_elements(By.CLASS_NAME, "dc")

            for table_element in table_elements:
                # Initialize data for each table
                table_data = {
                    "Player": [],
                    "Set 1": [],
                    "Set 2": [],
                    "Set 3": [],
                    "Tie-Break 1": [],
                    "Tie-Break 2": [],
                    "Tie-Break 3": []
                }

                # Find the table body
                tbody_element = table_element.find_element(By.TAG_NAME, "tbody")

                # Find all rows (tr elements) within the tbody
                rows = tbody_element.find_elements(By.TAG_NAME, "tr")

                for row in rows:
                    # Find all td elements within the row
                    td_elements = row.find_elements(By.TAG_NAME, "td")

                    # Extract and store the information starting from td_elements[1]
                    player = td_elements[1].text.strip()

                    # Skip set and tie-break infos if match hasn't been played
                    if match_status[match_idx] == "NOT PLAYED":
                        print(f"Skipping match {match_idx + 1}")
                        continue

                    # Extract results from td class "results"
                    results = td_elements[2]
                    set_scores = results.find_elements(By.TAG_NAME, "span")

                    set_results = []
                    tie_breaks = []

                    for set_score in set_scores:
                        set_result = set_score.text.strip()
                        tie_break = ""

                        # Use regular expressions to extract the first number in set_result
                        match = re.search(r'\d+', set_result)
                        if match:
                            set_result = match.group()
                        else:
                            set_result = ""

                        if set_score.find_elements(By.TAG_NAME, "sup"):
                            tie_break = set_score.find_element(By.TAG_NAME, "sup").text.strip()
                            # Use regular expressions to extract the first number in tie_break
                            match = re.search(r'\d+', tie_break)
                            if match:
                                tie_break = match.group()
                            else:
                                tie_break = ""

                        set_results.append(set_result)
                        tie_breaks.append(tie_break)

                    # Ensure there are at most 3 sets
                    set_results = set_results[:3]
                    tie_breaks = tie_breaks[:3]

                    # Assign the extracted values to the dictionary
                    table_data["Player"].append(player)
                    table_data["Set 1"].append(set_results[0])
                    table_data["Set 2"].append(set_results[1])
                    table_data["Set 3"].append(set_results[2])

                    # Keep only the first element in the list for tie-breaks
                    for i, tie_break in enumerate(tie_breaks):
                        if i == 0 and tie_break:
                            table_data["Tie-Break 1"].append(tie_break)
                        else:
                            table_data[f"Tie-Break {i + 1}"].append(None)

                # Append the table data to the list
                tables_data.append(table_data)
                print(table_data)

        # Close the Selenium WebDriver
        driver.quit()

        # Create a DataFrame from the collected data
        tables_df = pd.DataFrame(tables_data)

        # Combine the information from both DataFrames
        matches_df = pd.concat([df] * len(tables_df), ignore_index=True)
        matches_df = pd.concat([matches_df, tables_df], axis=1)

        # Add match and match status columns
        matches_df["match status"] = ""
        matches_df["match"] = ""
        for i in range(len(match_status)):
            matches_df.loc[i * 2:(i * 2) + 1, "match status"] = match_status[i]
            matches_df.loc[i * 2:(i * 2) + 1, "match"] = match_num[i]

        # Display the combined DataFrame
        print("Combined DataFrame:")
        print(matches_df)
        return matches_df
    except Exception as e:
        print("Error:", str(e))
        return None

# %%
def extract_players_df(url):
    try:
        # Initialize Selenium
        chrome_service = ChromeService("C:/Users/ALESSANDRO/Downloads/chromedriver.exe")
        chrome_service.start()
        chrome_options = Options()
        chrome_options.add_argument("--headless")
        driver = webdriver.Chrome(service=chrome_service, options=chrome_options)
        # Navigate to the webpage
        driver.get(url)

        # Wait for the page to load
        loaded = False
        while not loaded:
            try:
                main_element = driver.find_element(By.CLASS_NAME, "main")
                loaded = True
                print("Loaded!")
            except:
                time.sleep(1)
                print("waiting...")

        # Wait for the page to load
        driver.implicitly_wait(10)  # You can adjust the waiting time as needed

        # Find all div elements with class "team-nominations-col"
        team_nominations_col_elements = driver.find_elements(By.CLASS_NAME, "team-nominations-col")

        # Initialize a list to store the paired data
        paired_data = []

        # Initialize a list to store the column names
        column_names = set()

        # Loop through each "team-nominations-col" element
        for team_nominations_col_element in team_nominations_col_elements:
            # Extract the team name
            team_name_element = team_nominations_col_element.find_element(By.CLASS_NAME, "team-name")
            team_name = team_name_element.text.strip()

            # Find "players-info" elements and extract text from "ng-binding" elements
            players_info_elements = team_nominations_col_element.find_elements(By.CLASS_NAME, "players-info")

            for players_info_element in players_info_elements:
                ng_binding_elements = players_info_element.find_elements(By.CLASS_NAME, "ng-binding")

                # Create a dictionary for the row
                row_data = {"Team Name": team_name}

                for i, ng_binding_element in enumerate(ng_binding_elements, start=1):
                    row_data[f"Info {i}"] = ng_binding_element.text.strip()
                    column_names.add(f"Info {i}")

                paired_data.append(row_data)

        # Create a Pandas DataFrame from the paired data
        players_df = pd.DataFrame(paired_data)

        # Reorder columns to match the column names
        players_df = players_df[["Team Name"] + sorted(column_names)]

        # Now you have a DataFrame with team names and player information in separate columns
        print(players_df)

        return players_df

    except Exception as e:
        print("Error:", str(e))
        return None

# %% [markdown]
# # Extract links for all matches in a year and save them in lists

# %%
# Initialize Selenium WebDriver
driver = webdriver.Chrome(executable_path="C:/Users/ALESSANDRO/Downloads/chromedriver.exe")

# URL of the webpage
url = "https://www.daviscup.com/en/draws-results/historic-format/world-group.aspx"

# Navigate to the webpage
driver.get(url)

try:
    # Wait for the page to load
    driver.implicitly_wait(10)  # You can adjust the waiting time as needed

    # Find all links with class "tie-link" within the tables
    tie_links = driver.find_elements(By.CSS_SELECTOR, "table.tie.ng-scope a.tie-link")

    # Initialize a list to store the extracted links
    links = []

    # Extract the links
    for link in tie_links:
        href = link.get_attribute("href")
        links.append(href)

    # Create an empty list to store the results
    match_results = []
    player_results = []

    # Iterate through the links and apply the functions
    for link in links:
        matches_df = extract_matches_df(link)
        players_df = extract_players_df(link)
        
        if matches_df is not None:
            match_results.append(matches_df)
        if players_df is not None:
            player_results.append(players_df)

    # Close the Selenium WebDriver
    driver.quit()
    

except Exception as e:
    print("Error:", str(e))
finally:
    driver.quit()
# Out:
# C:\Users\ALESSANDRO\AppData\Local\Temp\ipykernel_19196\3869344487.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/ALESSANDRO/Downloads/chromedriver.exe")
# Loaded!
# {'Player': ['Adrian MANNARINO'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['3'], 'Tie-Break 1': ['4'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Thiemo DE BAKKER'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Richard GASQUET'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Robin HAASE'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Pierre-Hugues HERBERT\nNicolas MAHUT'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['8'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Robin HAASE\nJean-Julien ROJER'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['7'], 'Tie-Break 1': ['6'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Adrian MANNARINO'], 'Set 1': ['4'], 'Set 2': ['7'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Robin HAASE'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['5'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                  Venue  \
# 0   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 1   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 2   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 3   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 4   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 5   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 6   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 7   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 8   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 9   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#
#                                Surface               Ball  \
# 0   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 1   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 2   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 3   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 4   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 5   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 6   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 7   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 8   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 9   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#
#                     Stage                                  Player Set 1 Set 2  \
# 0  WORLD GROUP  1ST ROUND                      [Adrian MANNARINO]   [6]   [3]
# 1  WORLD GROUP  1ST ROUND                      [Thiemo DE BAKKER]   [7]   [6]
# 2  WORLD GROUP  1ST ROUND                       [Richard GASQUET]   [6]   [7]
# 3  WORLD GROUP  1ST ROUND                           [Robin HAASE]   [4]   [6]
# 4  WORLD GROUP  1ST ROUND  [Pierre-Hugues HERBERT\nNicolas MAHUT]   [7]   [6]
# 5  WORLD GROUP  1ST ROUND        [Robin HAASE\nJean-Julien ROJER]   [6]   [3]
# 6  WORLD GROUP  1ST ROUND                      [Adrian MANNARINO]   [4]   [7]
# 7  WORLD GROUP  1ST ROUND                           [Robin HAASE]   [6]   [6]
# 8  WORLD GROUP  1ST ROUND                                      []    []    []
# 9  WORLD GROUP  1ST ROUND                                      []    []    []
#
#   Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
# 0   [3]         [4]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1   [6]         [7]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2   [3]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4   [6]         [8]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5   [7]         [6]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7   [5]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8    []          []          []          []          NOT PLAYED  MATCH 5
# 9    []          []          []          []          NOT PLAYED  MATCH 5
# Loaded!
#       Team Name                 Info 1                      Info 2  \
# 0        FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 1        FRANCE       Adrian MANNARINO  Date of birth: 29 Jun 1988
# 2        FRANCE        Richard GASQUET  Date of birth: 18 Jun 1986
# 3        FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
# 4        FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 5        FRANCE                Captain                Yannick NOAH
# 6   NETHERLANDS            Robin HAASE  Date of birth: 06 Apr 1987
# 7   NETHERLANDS      Tallon GRIEKSPOOR  Date of birth: 02 Jul 1996
# 8   NETHERLANDS       Thiemo DE BAKKER  Date of birth: 19 Sep 1988
# 9   NETHERLANDS       Matwe MIDDELKOOP  Date of birth: 03 Sep 1983
# 10  NETHERLANDS      Jean-Julien ROJER  Date of birth: 25 Aug 1981
# 11  NETHERLANDS                Captain               Paul HAARHUIS
#
#                   Info 3                Info 4
# 0   Singles ranking: 333  Doubles ranking: 835
# 1    Singles ranking: 22  Doubles ranking: 286
# 2    Singles ranking: 79      Doubles ranking:
# 3   Singles ranking: 251   Doubles ranking: 74
# 4       Singles ranking:   Doubles ranking: 38
# 5                    NaN                   NaN
# 6   Singles ranking: 699   Doubles ranking: 41
# 7    Singles ranking: 23  Doubles ranking: 109
# 8   Singles ranking: 710  Doubles ranking: 686
# 9       Singles ranking:   Doubles ranking: 42
# 10      Singles ranking:   Doubles ranking: 18
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Taro DANIEL'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Fabio FOGNINI'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Yuichi SUGITA'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Andreas SEPPI'], 'Set 1': ['6'], 'Set 2': ['2'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ben MCLACHLAN\nYasutaka UCHIYAMA'], 'Set 1': ['5'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Simone BOLELLI\nFabio FOGNINI'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Yuichi SUGITA'], 'Set 1': ['6'], 'Set 2': ['1'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Fabio FOGNINI'], 'Set 1': ['3'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                  Venue  \
# 0   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 1   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 2   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 3   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 4   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 5   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 6   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 7   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 8   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 9   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#
#                         Surface Court Pace Rating     Ball  \
# 0   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 1   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 2   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 3   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 4   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 5   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 6   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 7   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 8   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 9   Hard - GreenSet Pro, Indoor              Fast   Srixon
#
#                     Stage                              Player Set 1 Set 2  \
# 0  WORLD GROUP  1ST ROUND                       [Taro DANIEL]   [4]   [6]
# 1  WORLD GROUP  1ST ROUND                     [Fabio FOGNINI]   [6]   [3]
# 2  WORLD GROUP  1ST ROUND                     [Yuichi SUGITA]   [4]   [6]
# 3  WORLD GROUP  1ST ROUND                     [Andreas SEPPI]   [6]   [2]
# 4  WORLD GROUP  1ST ROUND  [Ben MCLACHLAN\nYasutaka UCHIYAMA]   [5]   [7]
# 5  WORLD GROUP  1ST ROUND     [Simone BOLELLI\nFabio FOGNINI]   [7]   [6]
# 6  WORLD GROUP  1ST ROUND                     [Yuichi SUGITA]   [6]   [1]
# 7  WORLD GROUP  1ST ROUND                     [Fabio FOGNINI]   [3]   [6]
# 8  WORLD GROUP  1ST ROUND                                  []    []    []
# 9  WORLD GROUP  1ST ROUND                                  []    []    []
#
#   Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
# 0   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7   [3]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8    []          []          []          []          NOT PLAYED  MATCH 5
# 9    []          []          []          []          NOT PLAYED  MATCH 5
# Loaded!
#    Team Name             Info 1                      Info 2  \
# 0      JAPAN      Yuichi SUGITA  Date of birth: 18 Sep 1988
# 1      JAPAN        Taro DANIEL  Date of birth: 27 Jan 1993
# 2      JAPAN           Go SOEDA  Date of birth: 05 Sep 1984
# 3      JAPAN  Yasutaka UCHIYAMA  Date of birth: 05 Aug 1992
# 4      JAPAN      Ben MCLACHLAN  Date of birth: 10 May 1992
# 5      JAPAN            Captain            Satoshi IWABUCHI
# 6      ITALY      Fabio FOGNINI  Date of birth: 24 May 1987
# 7      ITALY      Paolo LORENZI  Date of birth: 15 Dec 1981
# 8      ITALY      Andreas SEPPI  Date of birth: 21 Feb 1984
# 9      ITALY    Thomas FABBIANO  Date of birth: 26 May 1989
# 10     ITALY     Simone BOLELLI  Date of birth: 08 Oct 1985
# 11     ITALY            Captain          Corrado BARAZZUTTI
#
#                   Info 3                Info 4
# 0   Singles ranking: 942      Doubles ranking:
# 1    Singles ranking: 78      Doubles ranking:
# 2       Singles ranking:      Doubles ranking:
# 3   Singles ranking: 301  Doubles ranking: 211
# 4       Singles ranking:   Doubles ranking: 78
# 5                    NaN                   NaN
# 6   Singles ranking: 129  Doubles ranking: 127
# 7       Singles ranking:      Doubles ranking:
# 8       Singles ranking:      Doubles ranking:
# 9       Singles ranking:      Doubles ranking:
# 10      Singles ranking:   Doubles ranking: 55
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Albert RAMOS-VINOLAS'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Liam BROADY'], 'Set 1': ['3'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Roberto BAUTISTA AGUT'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Cameron NORRIE'], 'Set 1': ['4'], 'Set 2': ['3'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Pablo CARRENO BUSTA\nFeliciano LOPEZ'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Dominic INGLOT\nJamie MURRAY'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Albert RAMOS-VINOLAS'], 'Set 1': ['7'], 'Set 2': ['2'], 'Set 3': ['7'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Cameron NORRIE'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['4'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                          Venue  \
# 0   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 1   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 2   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 3   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 4   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 5   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 6   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 7   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 8   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 9   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#
#                  Surface       Ball                   Stage  \
# 0   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 1   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 2   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 3   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 4   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 5   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 6   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 7   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 8   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 9   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#
#                                    Player Set 1 Set 2 Set 3 Tie-Break 1  \
# 0                  [Albert RAMOS-VINOLAS]   [6]   [6]   [7]      [None]
# 1                           [Liam BROADY]   [3]   [4]   [6]      [None]
# 2                 [Roberto BAUTISTA AGUT]   [6]   [6]   [3]      [None]
# 3                        [Cameron NORRIE]   [4]   [3]   [6]      [None]
# 4  [Pablo CARRENO BUSTA\nFeliciano LOPEZ]   [6]   [6]   [7]      [None]
# 5          [Dominic INGLOT\nJamie MURRAY]   [4]   [4]   [6]      [None]
# 6                  [Albert RAMOS-VINOLAS]   [7]   [2]   [7]         [7]
# 7                        [Cameron NORRIE]   [6]   [6]   [6]         [4]
# 8                                      []    []    []    []          []
# 9                                      []    []    []    []          []
#
#   Tie-Break 2 Tie-Break 3        match status    match
# 0      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8          []          []          NOT PLAYED  MATCH 5
# 9          []          []          NOT PLAYED  MATCH 5
# Loaded!
#         Team Name                 Info 1                      Info 2  \
# 0           SPAIN    Pablo CARRENO BUSTA  Date of birth: 12 Jul 1991
# 1           SPAIN   Albert RAMOS-VINOLAS  Date of birth: 17 Jan 1988
# 2           SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
# 3           SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
# 4           SPAIN           David FERRER  Date of birth: 02 Apr 1982
# 5           SPAIN                Captain              Sergi BRUGUERA
# 6   GREAT BRITAIN            Kyle EDMUND  Date of birth: 08 Jan 1995
# 7   GREAT BRITAIN         Cameron NORRIE  Date of birth: 23 Aug 1995
# 8   GREAT BRITAIN            Liam BROADY  Date of birth: 04 Jan 1994
# 9   GREAT BRITAIN           Jamie MURRAY  Date of birth: 13 Feb 1986
# 10  GREAT BRITAIN         Dominic INGLOT  Date of birth: 06 Mar 1986
# 11  GREAT BRITAIN                Captain                  Leon SMITH
#
#                   Info 3                Info 4
# 0   Singles ranking: 603      Doubles ranking:
# 1    Singles ranking: 94      Doubles ranking:
# 2    Singles ranking: 62      Doubles ranking:
# 3   Singles ranking: 460      Doubles ranking:
# 4       Singles ranking:      Doubles ranking:
# 5                    NaN                   NaN
# 6   Singles ranking: 527      Doubles ranking:
# 7    Singles ranking: 18  Doubles ranking: 195
# 8   Singles ranking: 102  Doubles ranking: 237
# 9       Singles ranking:  Doubles ranking: 16=
# 10      Singles ranking:      Doubles ranking:
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Alex DE MINAUR'], 'Set 1': ['5'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['7'], 'Set 2': ['4'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Nick KYRGIOS'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Jan-Lennard STRUFF'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Matthew EBDEN\nJohn PEERS'], 'Set 1': ['4'], 'Set 2': ['7'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Tim PUETZ\nJan-Lennard STRUFF'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Nick KYRGIOS'], 'Set 1': ['2'], 'Set 2': ['6'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                   Venue  \
# 0   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 1   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 2   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 3   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 4   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 5   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 6   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 7   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 8   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 9   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#
#                                   Surface Court Pace Rating  \
# 0   Hard - Plexicushion Prestige, Outdoor              Fast
# 1   Hard - Plexicushion Prestige, Outdoor              Fast
# 2   Hard - Plexicushion Prestige, Outdoor              Fast
# 3   Hard - Plexicushion Prestige, Outdoor              Fast
# 4   Hard - Plexicushion Prestige, Outdoor              Fast
# 5   Hard - Plexicushion Prestige, Outdoor              Fast
# 6   Hard - Plexicushion Prestige, Outdoor              Fast
# 7   Hard - Plexicushion Prestige, Outdoor              Fast
# 8   Hard - Plexicushion Prestige, Outdoor              Fast
# 9   Hard - Plexicushion Prestige, Outdoor              Fast
#
#                       Ball                   Stage  \
# 0   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 1   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 2   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 3   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 4   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 5   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 6   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 7   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 8   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 9   Wilson Australian Open  WORLD GROUP  1ST ROUND
#
#                             Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
# 0                 [Alex DE MINAUR]   [5]   [6]   [6]      [None]      [None]
# 1               [Alexander ZVEREV]   [7]   [4]   [4]      [None]      [None]
# 2                   [Nick KYRGIOS]   [6]   [6]   [6]      [None]      [None]
# 3             [Jan-Lennard STRUFF]   [4]   [4]   [4]      [None]      [None]
# 4      [Matthew EBDEN\nJohn PEERS]   [4]   [7]   [2]      [None]      [None]
# 5  [Tim PUETZ\nJan-Lennard STRUFF]   [6]   [6]   [6]      [None]      [None]
# 6                   [Nick KYRGIOS]   [2]   [6]   [2]      [None]      [None]
# 7               [Alexander ZVEREV]   [6]   [7]   [6]      [None]      [None]
# 8                               []    []    []    []          []          []
# 9                               []    []    []    []          []          []
#
#   Tie-Break 3        match status    match
# 0      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]  PLAYED & COMPLETED  MATCH 4
# 8          []          NOT PLAYED  MATCH 5
# 9          []          NOT PLAYED  MATCH 5
# Loaded!
#     Team Name              Info 1                      Info 2  \
# 0   AUSTRALIA        Nick KYRGIOS  Date of birth: 27 Apr 1995
# 1   AUSTRALIA       Matthew EBDEN  Date of birth: 26 Nov 1987
# 2   AUSTRALIA        John MILLMAN  Date of birth: 14 Jun 1989
# 3   AUSTRALIA      Alex DE MINAUR  Date of birth: 17 Feb 1999
# 4   AUSTRALIA          John PEERS  Date of birth: 25 Jul 1988
# 5   AUSTRALIA             Captain              Lleyton HEWITT
# 6     GERMANY    Alexander ZVEREV  Date of birth: 20 Apr 1997
# 7     GERMANY  Jan-Lennard STRUFF  Date of birth: 25 Apr 1990
# 8     GERMANY     Peter GOJOWCZYK  Date of birth: 15 Jul 1989
# 9     GERMANY           Tim PUETZ  Date of birth: 19 Nov 1987
# 10    GERMANY             Captain            Michael KOHLMANN
#
#                   Info 3                 Info 4
# 0       Singles ranking:       Doubles ranking:
# 1       Singles ranking:     Doubles ranking: 4
# 2   Singles ranking: 437       Doubles ranking:
# 3    Singles ranking: 12   Doubles ranking: 176
# 4       Singles ranking:    Doubles ranking: 39
# 5                    NaN                    NaN
# 6     Singles ranking: 7  Doubles ranking: 197=
# 7    Singles ranking: 25   Doubles ranking: 285
# 8   Singles ranking: 372       Doubles ranking:
# 9       Singles ranking:    Doubles ranking: 24
# 10                   NaN                    NaN
# Loaded!
# {'Player': ['Dmitry POPKO'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Henri LAAKSONEN'], 'Set 1': ['2'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Mikhail KUKUSHKIN'], 'Set 1': ['3'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Adrian BODMER'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Timur KHABIBULIN\nAleksandr NEDOVYESOV'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marc-Andrea HUESLER\nLuca MARGAROLI'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Error: list index out of range
# Loaded!
#       Team Name                Info 1                      Info 2  \
# 0    KAZAKHSTAN     Mikhail KUKUSHKIN  Date of birth: 26 Dec 1987
# 1    KAZAKHSTAN          Dmitry POPKO  Date of birth: 24 Oct 1996
# 2    KAZAKHSTAN  Aleksandr NEDOVYESOV  Date of birth: 15 Feb 1987
# 3    KAZAKHSTAN       Roman KHASSANOV  Date of birth: 07 Sep 1996
# 4    KAZAKHSTAN      Timur KHABIBULIN  Date of birth: 02 Aug 1995
# 5    KAZAKHSTAN               Captain             Dias DOSKARAYEV
# 6   SWITZERLAND       Henri LAAKSONEN  Date of birth: 31 Mar 1992
# 7   SWITZERLAND         Adrian BODMER  Date of birth: 06 Mar 1995
# 8   SWITZERLAND   Marc-Andrea HUESLER  Date of birth: 24 Jun 1996
# 9   SWITZERLAND       Antoine BELLIER  Date of birth: 18 Oct 1996
# 10  SWITZERLAND        Luca MARGAROLI  Date of birth: 15 Feb 1992
# 11  SWITZERLAND               Captain               Severin LUTHI
#
#                     Info 3                 Info 4
# 0     Singles ranking: 210       Doubles ranking:
# 1     Singles ranking: 506  Doubles ranking: 903=
# 2         Singles ranking:    Doubles ranking: 44
# 3         Singles ranking:       Doubles ranking:
# 4         Singles ranking:       Doubles ranking:
# 5                      NaN                    NaN
# 6     Singles ranking: 556       Doubles ranking:
# 7   Singles ranking: 1673=       Doubles ranking:
# 8     Singles ranking: 197   Doubles ranking: 236
# 9     Singles ranking: 243   Doubles ranking: 492
# 10        Singles ranking:   Doubles ranking: 144
# 11                     NaN                    NaN
# Loaded!
# Error: Message: no such element: Unable to locate element: {"method":"css selector","selector":".component-title"}
#   (Session info: headless chrome=119.0.6045.160)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF644A782B2+55298]
# 	(No symbol) [0x00007FF6449E5E02]
# 	(No symbol) [0x00007FF6448A05AB]
# 	(No symbol) [0x00007FF6448E175C]
# 	(No symbol) [0x00007FF6448E18DC]
# 	(No symbol) [0x00007FF6448D819C]
# 	(No symbol) [0x00007FF6449020EF]
# 	(No symbol) [0x00007FF6448D80CF]
# 	(No symbol) [0x00007FF6449022C0]
# 	(No symbol) [0x00007FF64491AAA4]
# 	(No symbol) [0x00007FF644901E83]
# 	(No symbol) [0x00007FF6448D670A]
# 	(No symbol) [0x00007FF6448D7964]
# 	GetHandleVerifier [0x00007FF644DF0AAB+3694587]
# 	GetHandleVerifier [0x00007FF644E4728E+4048862]
# 	GetHandleVerifier [0x00007FF644E3F173+4015811]
# 	GetHandleVerifier [0x00007FF644B147D6+695590]
# 	(No symbol) [0x00007FF6449F0CE8]
# 	(No symbol) [0x00007FF6449ECF34]
# 	(No symbol) [0x00007FF6449ED062]
# 	(No symbol) [0x00007FF6449DD3A3]
# 	BaseThreadInitThunk [0x00007FFA34F9257D+29]
# 	RtlUserThreadStart [0x00007FFA3722AA58+40]
# Loaded!
# Error: "None of [Index(['Team Name'], dtype='object')] are in the [columns]"
# Loaded!
# Error: Message: no such element: Unable to locate element: {"method":"css selector","selector":".component-title"}
#   (Session info: headless chrome=119.0.6045.160)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF644A782B2+55298]
# 	(No symbol) [0x00007FF6449E5E02]
# 	(No symbol) [0x00007FF6448A05AB]
# 	(No symbol) [0x00007FF6448E175C]
# 	(No symbol) [0x00007FF6448E18DC]
# 	(No symbol) [0x00007FF6448D819C]
# 	(No symbol) [0x00007FF6449020EF]
# 	(No symbol) [0x00007FF6448D80CF]
# 	(No symbol) [0x00007FF6449022C0]
# 	(No symbol) [0x00007FF64491AAA4]
# 	(No symbol) [0x00007FF644901E83]
# 	(No symbol) [0x00007FF6448D670A]
# 	(No symbol) [0x00007FF6448D7964]
# 	GetHandleVerifier [0x00007FF644DF0AAB+3694587]
# 	GetHandleVerifier [0x00007FF644E4728E+4048862]
# 	GetHandleVerifier [0x00007FF644E3F173+4015811]
# 	GetHandleVerifier [0x00007FF644B147D6+695590]
# 	(No symbol) [0x00007FF6449F0CE8]
# 	(No symbol) [0x00007FF6449ECF34]
# 	(No symbol) [0x00007FF6449ED062]
# 	(No symbol) [0x00007FF6449DD3A3]
# 	BaseThreadInitThunk [0x00007FFA34F9257D+29]
# 	RtlUserThreadStart [0x00007FFA3722AA58+40]
#
# Loaded!
# Error: "None of [Index(['Team Name'], dtype='object')] are in the [columns]"
# Loaded!
# Error: Message: no such element: Unable to locate element: {"method":"css selector","selector":".component-title"}
#   (Session info: headless chrome=119.0.6045.160)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF644A782B2+55298]
# 	(No symbol) [0x00007FF6449E5E02]
# 	(No symbol) [0x00007FF6448A05AB]
# 	(No symbol) [0x00007FF6448E175C]
# 	(No symbol) [0x00007FF6448E18DC]
# 	(No symbol) [0x00007FF6448D819C]
# 	(No symbol) [0x00007FF6449020EF]
# 	(No symbol) [0x00007FF6448D80CF]
# 	(No symbol) [0x00007FF6449022C0]
# 	(No symbol) [0x00007FF64491AAA4]
# 	(No symbol) [0x00007FF644901E83]
# 	(No symbol) [0x00007FF6448D670A]
# 	(No symbol) [0x00007FF6448D7964]
# 	GetHandleVerifier [0x00007FF644DF0AAB+3694587]
# 	GetHandleVerifier [0x00007FF644E4728E+4048862]
# 	GetHandleVerifier [0x00007FF644E3F173+4015811]
# 	GetHandleVerifier [0x00007FF644B147D6+695590]
# 	(No symbol) [0x00007FF6449F0CE8]
# 	(No symbol) [0x00007FF6449ECF34]
# 	(No symbol) [0x00007FF6449ED062]
# 	(No symbol) [0x00007FF6449DD3A3]
# 	BaseThreadInitThunk [0x00007FFA34F9257D+29]
# 	RtlUserThreadStart [0x00007FFA3722AA58+40]
#
# Loaded!
# Error: "None of [Index(['Team Name'], dtype='object')] are in the [columns]"
# Loaded!
# Error: Message: no such element: Unable to locate element: {"method":"css selector","selector":".component-title"}
#   (Session info: headless chrome=119.0.6045.160)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF644A782B2+55298]
# 	(No symbol) [0x00007FF6449E5E02]
# 	(No symbol) [0x00007FF6448A05AB]
# 	(No symbol) [0x00007FF6448E175C]
# 	(No symbol) [0x00007FF6448E18DC]
# 	(No symbol) [0x00007FF6448D819C]
# 	(No symbol) [0x00007FF6449020EF]
# 	(No symbol) [0x00007FF6448D80CF]
# 	(No symbol) [0x00007FF6449022C0]
# 	(No symbol) [0x00007FF64491AAA4]
# 	(No symbol) [0x00007FF644901E83]
# 	(No symbol) [0x00007FF6448D670A]
# 	(No symbol) [0x00007FF6448D7964]
# 	GetHandleVerifier [0x00007FF644DF0AAB+3694587]
# 	GetHandleVerifier [0x00007FF644E4728E+4048862]
# 	GetHandleVerifier [0x00007FF644E3F173+4015811]
# 	GetHandleVerifier [0x00007FF644B147D6+695590]
# 	(No symbol) [0x00007FF6449F0CE8]
# 	(No symbol) [0x00007FF6449ECF34]
# 	(No symbol) [0x00007FF6449ED062]
# 	(No symbol) [0x00007FF6449DD3A3]
# 	BaseThreadInitThunk [0x00007FFA34F9257D+29]
# 	RtlUserThreadStart [0x00007FFA3722AA58+40]
#
# Loaded!
#    Team Name                 Info 1                      Info 2  \
# 0                     Fabio FOGNINI  Date of birth: 24 May 1987
# 1                     Paolo LORENZI  Date of birth: 15 Dec 1981
# 2                     Andreas SEPPI  Date of birth: 21 Feb 1984
# 3                 Matteo BERRETTINI  Date of birth: 12 Apr 1996
# 4                    Simone BOLELLI  Date of birth: 08 Oct 1985
# 5                           Captain          Corrado BARAZZUTTI
# 6     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 7     FRANCE       Adrian MANNARINO  Date of birth: 29 Jun 1988
# 8     FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
# 9     FRANCE          Jeremy CHARDY  Date of birth: 12 Feb 1987
# 10    FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 11    FRANCE                Captain                Yannick NOAH
#
#                   Info 3                Info 4
# 0   Singles ranking: 129  Doubles ranking: 127
# 1       Singles ranking:      Doubles ranking:
# 2       Singles ranking:      Doubles ranking:
# 3    Singles ranking: 90      Doubles ranking:
# 4       Singles ranking:   Doubles ranking: 55
# 5                    NaN                   NaN
# 6   Singles ranking: 333  Doubles ranking: 835
# 7    Singles ranking: 22  Doubles ranking: 286
# 8   Singles ranking: 251   Doubles ranking: 74
# 9   Singles ranking: 505  Doubles ranking: 113
# 10      Singles ranking:   Doubles ranking: 38
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['David FERRER'], 'Set 1': ['4'], 'Set 2': ['2'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Rafael NADAL'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Philipp KOHLSCHREIBER'], 'Set 1': ['2'], 'Set 2': ['2'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Feliciano LOPEZ\nMarc LOPEZ'], 'Set 1': ['3'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Tim PUETZ\nJan-Lennard STRUFF'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Rafael NADAL'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['1'], 'Set 2': ['4'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['David FERRER'], 'Set 1': ['7'], 'Set 2': ['3'], 'Set 3': ['7'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Philipp KOHLSCHREIBER'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['1'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Combined DataFrame:
#                     Date                                         Venue  \
# 0   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 1   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 2   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 3   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 4   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 5   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 6   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 7   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 8   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 9   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#
#                      Surface             Ball                      Stage  \
# 0   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 1   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 2   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 3   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 4   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 5   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 6   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 7   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 8   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 9   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#
#                             Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
# 0                   [David FERRER]   [4]   [2]   [2]      [None]      [None]
# 1               [Alexander ZVEREV]   [6]   [6]   [6]      [None]      [None]
# 2                   [Rafael NADAL]   [6]   [6]   [6]      [None]      [None]
# 3          [Philipp KOHLSCHREIBER]   [2]   [2]   [3]      [None]      [None]
# 4    [Feliciano LOPEZ\nMarc LOPEZ]   [3]   [4]   [6]      [None]      [None]
# 5  [Tim PUETZ\nJan-Lennard STRUFF]   [6]   [6]   [3]      [None]      [None]
# 6                   [Rafael NADAL]   [6]   [6]   [6]      [None]      [None]
# 7               [Alexander ZVEREV]   [1]   [4]   [4]      [None]      [None]
# 8                   [David FERRER]   [7]   [3]   [7]         [7]      [None]
# 9          [Philipp KOHLSCHREIBER]   [6]   [6]   [6]         [1]      [None]
#
#   Tie-Break 3        match status    match
# 0      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]  PLAYED & COMPLETED  MATCH 4
# 8      [None]  PLAYED & COMPLETED  MATCH 5
# 9      [None]  PLAYED & COMPLETED  MATCH 5
# Loaded!
#    Team Name                 Info 1                      Info 2  \
# 0      SPAIN           Rafael NADAL  Date of birth: 03 Jun 1986
# 1      SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
# 2      SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
# 3      SPAIN           David FERRER  Date of birth: 02 Apr 1982
# 4      SPAIN                Captain              Sergi BRUGUERA
# 5    GERMANY       Alexander ZVEREV  Date of birth: 20 Apr 1997
# 6    GERMANY  Philipp KOHLSCHREIBER  Date of birth: 16 Oct 1983
# 7    GERMANY     Jan-Lennard STRUFF  Date of birth: 25 Apr 1990
# 8    GERMANY    Maximilian MARTERER  Date of birth: 15 Jun 1995
# 9    GERMANY              Tim PUETZ  Date of birth: 19 Nov 1987
# 10   GERMANY                Captain            Michael KOHLMANN
#
#                   Info 3                 Info 4
# 0   Singles ranking: 664       Doubles ranking:
# 1    Singles ranking: 62       Doubles ranking:
# 2   Singles ranking: 460       Doubles ranking:
# 3       Singles ranking:       Doubles ranking:
# 4                    NaN                    NaN
# 5     Singles ranking: 7  Doubles ranking: 197=
# 6       Singles ranking:       Doubles ranking:
# 7    Singles ranking: 25   Doubles ranking: 285
# 8   Singles ranking: 100   Doubles ranking: 715
# 9       Singles ranking:    Doubles ranking: 24
# 10                   NaN                    NaN
# Loaded!
# Error: No objects to concatenate
# Loaded!
#      Team Name                Info 1                      Info 2  \
# 0      CROATIA           Marin CILIC  Date of birth: 28 Sep 1988
# 1      CROATIA           Borna CORIC  Date of birth: 14 Nov 1996
# 2      CROATIA        Viktor GALOVIC  Date of birth: 19 Sep 1990
# 3      CROATIA            Ivan DODIG  Date of birth: 02 Jan 1985
# 4      CROATIA         Nikola MEKTIC  Date of birth: 24 Dec 1988
# 5      CROATIA               Captain               Zeljko KRAJAN
# 6   KAZAKHSTAN     Mikhail KUKUSHKIN  Date of birth: 26 Dec 1987
# 7   KAZAKHSTAN  Aleksandr NEDOVYESOV  Date of birth: 15 Feb 1987
# 8   KAZAKHSTAN          Dmitry POPKO  Date of birth: 24 Oct 1996
# 9   KAZAKHSTAN        Denis YEVSEYEV  Date of birth: 22 May 1993
# 10  KAZAKHSTAN      Timur KHABIBULIN  Date of birth: 02 Aug 1995
# 11  KAZAKHSTAN               Captain             Dias DOSKARAYEV
#
#                   Info 3                 Info 4
# 0   Singles ranking: 666       Doubles ranking:
# 1    Singles ranking: 37       Doubles ranking:
# 2       Singles ranking:       Doubles ranking:
# 3       Singles ranking:     Doubles ranking: 2
# 4       Singles ranking:    Doubles ranking: 43
# 5                    NaN                    NaN
# 6   Singles ranking: 210       Doubles ranking:
# 7       Singles ranking:    Doubles ranking: 44
# 8   Singles ranking: 506  Doubles ranking: 903=
# 9   Singles ranking: 228   Doubles ranking: 540
# 10      Singles ranking:       Doubles ranking:
# 11                   NaN                    NaN
# Loaded!
# {'Player': ['John ISNER'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Joris DE LOORE'], 'Set 1': ['3'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Sam QUERREY'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ruben BEMELMANS'], 'Set 1': ['1'], 'Set 2': ['6'], 'Set 3': ['5'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ryan HARRISON\nJack SOCK'], 'Set 1': ['5'], 'Set 2': ['7'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Sander GILLE\nJoran VLIEGEN'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Error: list index out of range
# Loaded!
#    Team Name           Info 1                      Info 2  \
# 0        USA       John ISNER  Date of birth: 26 Apr 1985
# 1        USA      Sam QUERREY  Date of birth: 07 Oct 1987
# 2        USA        Jack SOCK  Date of birth: 24 Sep 1992
# 3        USA    Steve JOHNSON  Date of birth: 24 Dec 1989
# 4        USA    Ryan HARRISON  Date of birth: 07 May 1992
# 5        USA          Captain                 Jim COURIER
# 6    BELGIUM  Ruben BEMELMANS  Date of birth: 14 Jan 1988
# 7    BELGIUM   Joris DE LOORE  Date of birth: 21 Apr 1993
# 8    BELGIUM     Sander GILLE  Date of birth: 15 Jan 1991
# 9    BELGIUM    Joran VLIEGEN  Date of birth: 07 Jul 1993
# 10   BELGIUM          Captain             Johan VAN HERCK
#
#                   Info 3                 Info 4
# 0   Singles ranking: 175   Doubles ranking: 194
# 1       Singles ranking:       Doubles ranking:
# 2   Singles ranking: 665   Doubles ranking: 192
# 3   Singles ranking: 226       Doubles ranking:
# 4   Singles ranking: 828   Doubles ranking: 834
# 5                    NaN                    NaN
# 6       Singles ranking:       Doubles ranking:
# 7   Singles ranking: 145  Doubles ranking: 854=
# 8       Singles ranking:   Doubles ranking: 25=
# 9       Singles ranking:   Doubles ranking: 25=
# 10                   NaN                    NaN
# Loaded!
# Error: No objects to concatenate
# Loaded!
#    Team Name                 Info 1                      Info 2  \
# 0                     Lucas POUILLE  Date of birth: 23 Feb 1994
# 1                   Richard GASQUET  Date of birth: 18 Jun 1986
# 2                      Benoit PAIRE  Date of birth: 08 May 1989
# 3                  Julien BENNETEAU  Date of birth: 20 Dec 1981
# 4                     Nicolas MAHUT  Date of birth: 21 Jan 1982
# 5                           Captain                Yannick NOAH
# 6      SPAIN    Pablo CARRENO BUSTA  Date of birth: 12 Jul 1991
# 7      SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
# 8      SPAIN   Albert RAMOS-VINOLAS  Date of birth: 17 Jan 1988
# 9      SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
# 10     SPAIN      Marcel GRANOLLERS  Date of birth: 12 Apr 1986
# 11     SPAIN                Captain              Sergi BRUGUERA
#
#                   Info 3                Info 4
# 0   Singles ranking: 333  Doubles ranking: 835
# 1    Singles ranking: 79      Doubles ranking:
# 2   Singles ranking: 126  Doubles ranking: 526
# 3       Singles ranking:      Doubles ranking:
# 4       Singles ranking:   Doubles ranking: 38
# 5                    NaN                   NaN
# 6   Singles ranking: 603      Doubles ranking:
# 7    Singles ranking: 62      Doubles ranking:
# 8    Singles ranking: 94      Doubles ranking:
# 9   Singles ranking: 460      Doubles ranking:
# 10      Singles ranking:   Doubles ranking: 10
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Borna CORIC'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Steve JOHNSON'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marin CILIC'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Frances TIAFOE'], 'Set 1': ['1'], 'Set 2': ['3'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ivan DODIG\nMate PAVIC'], 'Set 1': ['5'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Mike BRYAN\nRyan HARRISON'], 'Set 1': ['7'], 'Set 2': ['7'], 'Set 3': ['1'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marin CILIC'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Sam QUERREY'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': ['2'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Borna CORIC'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['0'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Frances TIAFOE'], 'Set 1': ['7'], 'Set 2': ['1'], 'Set 3': ['7'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Combined DataFrame:
#                     Date                                     Venue  \
# 0   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 1   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 2   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 3   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 4   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 5   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 6   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 7   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 8   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 9   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#
#                      Surface                     Ball                   Stage  \
# 0   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 1   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 2   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 3   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 4   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 5   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 6   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 7   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 8   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 9   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#
#                         Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
# 0                [Borna CORIC]   [6]   [7]   [6]      [None]      [None]
# 1              [Steve JOHNSON]   [4]   [6]   [3]      [None]      [None]
# 2                [Marin CILIC]   [6]   [6]   [7]      [None]      [None]
# 3             [Frances TIAFOE]   [1]   [3]   [6]      [None]      [None]
# 4     [Ivan DODIG\nMate PAVIC]   [5]   [6]   [6]      [None]      [None]
# 5  [Mike BRYAN\nRyan HARRISON]   [7]   [7]   [1]      [None]      [None]
# 6                [Marin CILIC]   [7]   [6]   [3]         [7]      [None]
# 7                [Sam QUERREY]   [6]   [7]   [6]         [2]      [None]
# 8                [Borna CORIC]   [6]   [6]   [6]         [0]      [None]
# 9             [Frances TIAFOE]   [7]   [1]   [7]         [7]      [None]
#
#   Tie-Break 3        match status    match
# 0      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]  PLAYED & COMPLETED  MATCH 4
# 8      [None]  PLAYED & COMPLETED  MATCH 5
# 9      [None]  PLAYED & COMPLETED  MATCH 5
# Loaded!
#    Team Name          Info 1                      Info 2  \
# 0    CROATIA     Marin CILIC  Date of birth: 28 Sep 1988
# 1    CROATIA     Borna CORIC  Date of birth: 14 Nov 1996
# 2    CROATIA   Franko SKUGOR  Date of birth: 20 Sep 1987
# 3    CROATIA      Mate PAVIC  Date of birth: 04 Jul 1993
# 4    CROATIA      Ivan DODIG  Date of birth: 02 Jan 1985
# 5    CROATIA         Captain               Zeljko KRAJAN
# 6        USA   Steve JOHNSON  Date of birth: 24 Dec 1989
# 7        USA  Frances TIAFOE  Date of birth: 20 Jan 1998
# 8        USA   Ryan HARRISON  Date of birth: 07 May 1992
# 9        USA     Sam QUERREY  Date of birth: 07 Oct 1987
# 10       USA      Mike BRYAN  Date of birth: 29 Apr 1978
# 11       USA         Captain                 Jim COURIER
#
#                   Info 3                Info 4
# 0   Singles ranking: 666      Doubles ranking:
# 1    Singles ranking: 37      Doubles ranking:
# 2       Singles ranking:  Doubles ranking: 169
# 3       Singles ranking:   Doubles ranking: 32
# 4       Singles ranking:    Doubles ranking: 2
# 5                    NaN                   NaN
# 6   Singles ranking: 226      Doubles ranking:
# 7    Singles ranking: 16  Doubles ranking: 196
# 8   Singles ranking: 828  Doubles ranking: 834
# 9       Singles ranking:      Doubles ranking:
# 10      Singles ranking:      Doubles ranking:
# 11                   NaN                   NaN
# Loaded!
# Error: No objects to concatenate
# Loaded!
#    Team Name                 Info 1                      Info 2  \
# 0     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 1     FRANCE          Jeremy CHARDY  Date of birth: 12 Feb 1987
# 2     FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
# 3     FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 4     FRANCE     Jo-Wilfried TSONGA  Date of birth: 17 Apr 1985
# 5     FRANCE                Captain                Yannick NOAH
# 6    CROATIA            Marin CILIC  Date of birth: 28 Sep 1988
# 7    CROATIA            Borna CORIC  Date of birth: 14 Nov 1996
# 8    CROATIA          Franko SKUGOR  Date of birth: 20 Sep 1987
# 9    CROATIA             Mate PAVIC  Date of birth: 04 Jul 1993
# 10   CROATIA             Ivan DODIG  Date of birth: 02 Jan 1985
# 11   CROATIA                Captain               Zeljko KRAJAN
#
#                   Info 3                Info 4
# 0   Singles ranking: 333  Doubles ranking: 835
# 1   Singles ranking: 505  Doubles ranking: 113
# 2   Singles ranking: 251   Doubles ranking: 74
# 3       Singles ranking:   Doubles ranking: 38
# 4       Singles ranking:      Doubles ranking:
# 5                    NaN                   NaN
# 6   Singles ranking: 666      Doubles ranking:
# 7    Singles ranking: 37      Doubles ranking:
# 8       Singles ranking:  Doubles ranking: 169
# 9       Singles ranking:   Doubles ranking: 32
# 10      Singles ranking:    Doubles ranking: 2
# 11                   NaN                   NaN

# %% [markdown]
# ## output

# %%
match_results
# Out:
# [                    Date                                  Venue  \
#  0   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  1   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  2   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  3   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  4   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  5   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  6   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  7   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  8   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#  9   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#
#                                 Surface               Ball  \
#  0   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  1   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  2   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  3   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  4   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  5   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  6   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  7   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  8   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#  9   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#
#                      Stage                                  Player Set 1 Set 2  \
#  0  WORLD GROUP  1ST ROUND                      [Adrian MANNARINO]   [6]   [3]
#  1  WORLD GROUP  1ST ROUND                      [Thiemo DE BAKKER]   [7]   [6]
#  2  WORLD GROUP  1ST ROUND                       [Richard GASQUET]   [6]   [7]
#  3  WORLD GROUP  1ST ROUND                           [Robin HAASE]   [4]   [6]
#  4  WORLD GROUP  1ST ROUND  [Pierre-Hugues HERBERT\nNicolas MAHUT]   [7]   [6]
#  5  WORLD GROUP  1ST ROUND        [Robin HAASE\nJean-Julien ROJER]   [6]   [3]
#  6  WORLD GROUP  1ST ROUND                      [Adrian MANNARINO]   [4]   [7]
#  7  WORLD GROUP  1ST ROUND                           [Robin HAASE]   [6]   [6]
#  8  WORLD GROUP  1ST ROUND                                      []    []    []
#  9  WORLD GROUP  1ST ROUND                                      []    []    []
#
#    Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
#  0   [3]         [4]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
#  1   [6]         [7]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
#  2   [3]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
#  3   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
#  4   [6]         [8]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
#  5   [7]         [6]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
#  6   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
#  7   [5]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
#  8    []          []          []          []          NOT PLAYED  MATCH 5
#  9    []          []          []          []          NOT PLAYED  MATCH 5  ,
#                      Date                                  Venue  \
#  0   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  1   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  2   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  3   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  4   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  5   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  6   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  7   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  8   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#  9   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#
#                          Surface Court Pace Rating     Ball  \
#  0   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  1   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  2   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  3   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  4   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  5   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  6   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  7   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  8   Hard - GreenSet Pro, Indoor              Fast   Srixon
#  9   Hard - GreenSet Pro, Indoor              Fast   Srixon
#
#                      Stage                              Player Set 1 Set 2  \
#  0  WORLD GROUP  1ST ROUND                       [Taro DANIEL]   [4]   [6]
#  1  WORLD GROUP  1ST ROUND                     [Fabio FOGNINI]   [6]   [3]
#  2  WORLD GROUP  1ST ROUND                     [Yuichi SUGITA]   [4]   [6]
#  3  WORLD GROUP  1ST ROUND                     [Andreas SEPPI]   [6]   [2]
#  4  WORLD GROUP  1ST ROUND  [Ben MCLACHLAN\nYasutaka UCHIYAMA]   [5]   [7]
#  5  WORLD GROUP  1ST ROUND     [Simone BOLELLI\nFabio FOGNINI]   [7]   [6]
#  6  WORLD GROUP  1ST ROUND                     [Yuichi SUGITA]   [6]   [1]
#  7  WORLD GROUP  1ST ROUND                     [Fabio FOGNINI]   [3]   [6]
#  8  WORLD GROUP  1ST ROUND                                  []    []    []
#  9  WORLD GROUP  1ST ROUND                                  []    []    []
#
#    Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
#  0   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
#  1   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
#  2   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
#  3   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
#  4   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
#  5   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
#  6   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
#  7   [3]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
#  8    []          []          []          []          NOT PLAYED  MATCH 5
#  9    []          []          []          []          NOT PLAYED  MATCH 5  ,
#                      Date                                          Venue  \
#  0   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  1   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  2   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  3   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  4   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  5   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  6   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  7   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  8   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#  9   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#
#                   Surface       Ball                   Stage  \
#  0   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  1   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  2   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  3   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  4   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  5   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  6   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  7   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  8   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#  9   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#
#                                     Player Set 1 Set 2 Set 3 Tie-Break 1  \
#  0                  [Albert RAMOS-VINOLAS]   [6]   [6]   [7]      [None]
#  1                           [Liam BROADY]   [3]   [4]   [6]      [None]
#  2                 [Roberto BAUTISTA AGUT]   [6]   [6]   [3]      [None]
#  3                        [Cameron NORRIE]   [4]   [3]   [6]      [None]
#  4  [Pablo CARRENO BUSTA\nFeliciano LOPEZ]   [6]   [6]   [7]      [None]
#  5          [Dominic INGLOT\nJamie MURRAY]   [4]   [4]   [6]      [None]
#  6                  [Albert RAMOS-VINOLAS]   [7]   [2]   [7]         [7]
#  7                        [Cameron NORRIE]   [6]   [6]   [6]         [4]
#  8                                      []    []    []    []          []
#  9                                      []    []    []    []          []
#
#    Tie-Break 2 Tie-Break 3        match status    match
#  0      [None]      [None]  PLAYED & COMPLETED  MATCH 1
#  1      [None]      [None]  PLAYED & COMPLETED  MATCH 1
#  2      [None]      [None]  PLAYED & COMPLETED  MATCH 2
#  3      [None]      [None]  PLAYED & COMPLETED  MATCH 2
#  4      [None]      [None]  PLAYED & COMPLETED  MATCH 3
#  5      [None]      [None]  PLAYED & COMPLETED  MATCH 3
#  6      [None]      [None]  PLAYED & COMPLETED  MATCH 4
#  7      [None]      [None]  PLAYED & COMPLETED  MATCH 4
#  8          []          []          NOT PLAYED  MATCH 5
#  9          []          []          NOT PLAYED  MATCH 5  ,
#                      Date                                   Venue  \
#  0   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  1   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  2   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  3   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  4   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  5   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  6   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  7   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  8   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#  9   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#
#                                    Surface Court Pace Rating  \
#  0   Hard - Plexicushion Prestige, Outdoor              Fast
#  1   Hard - Plexicushion Prestige, Outdoor              Fast
#  2   Hard - Plexicushion Prestige, Outdoor              Fast
#  3   Hard - Plexicushion Prestige, Outdoor              Fast
#  4   Hard - Plexicushion Prestige, Outdoor              Fast
#  5   Hard - Plexicushion Prestige, Outdoor              Fast
#  6   Hard - Plexicushion Prestige, Outdoor              Fast
#  7   Hard - Plexicushion Prestige, Outdoor              Fast
#  8   Hard - Plexicushion Prestige, Outdoor              Fast
#  9   Hard - Plexicushion Prestige, Outdoor              Fast
#
#                        Ball                   Stage  \
#  0   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  1   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  2   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  3   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  4   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  5   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  6   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  7   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  8   Wilson Australian Open  WORLD GROUP  1ST ROUND
#  9   Wilson Australian Open  WORLD GROUP  1ST ROUND
#
#                              Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
#  0                 [Alex DE MINAUR]   [5]   [6]   [6]      [None]      [None]
#  1               [Alexander ZVEREV]   [7]   [4]   [4]      [None]      [None]
#  2                   [Nick KYRGIOS]   [6]   [6]   [6]      [None]      [None]
#  3             [Jan-Lennard STRUFF]   [4]   [4]   [4]      [None]      [None]
#  4      [Matthew EBDEN\nJohn PEERS]   [4]   [7]   [2]      [None]      [None]
#  5  [Tim PUETZ\nJan-Lennard STRUFF]   [6]   [6]   [6]      [None]      [None]
#  6                   [Nick KYRGIOS]   [2]   [6]   [2]      [None]      [None]
#  7               [Alexander ZVEREV]   [6]   [7]   [6]      [None]      [None]
#  8                               []    []    []    []          []          []
#  9                               []    []    []    []          []          []
#
#    Tie-Break 3        match status    match
#  0      [None]  PLAYED & COMPLETED  MATCH 1
#  1      [None]  PLAYED & COMPLETED  MATCH 1
#  2      [None]  PLAYED & COMPLETED  MATCH 2
#  3      [None]  PLAYED & COMPLETED  MATCH 2
#  4      [None]  PLAYED & COMPLETED  MATCH 3
#  5      [None]  PLAYED & COMPLETED  MATCH 3
#  6      [None]  PLAYED & COMPLETED  MATCH 4
#  7      [None]  PLAYED & COMPLETED  MATCH 4
#  8          []          NOT PLAYED  MATCH 5
#  9          []          NOT PLAYED  MATCH 5  ,
#                      Date                                         Venue  \
#  0   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  1   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  2   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  3   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  4   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  5   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  6   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  7   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  8   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#  9   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#
#                       Surface             Ball                      Stage  \
#  0   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  1   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  2   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  3   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  4   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  5   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  6   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  7   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  8   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#  9   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#
#                              Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
#  0                   [David FERRER]   [4]   [2]   [2]      [None]      [None]
#  1               [Alexander ZVEREV]   [6]   [6]   [6]      [None]      [None]
#  2                   [Rafael NADAL]   [6]   [6]   [6]      [None]      [None]
#  3          [Philipp KOHLSCHREIBER]   [2]   [2]   [3]      [None]      [None]
#  4    [Feliciano LOPEZ\nMarc LOPEZ]   [3]   [4]   [6]      [None]      [None]
#  5  [Tim PUETZ\nJan-Lennard STRUFF]   [6]   [6]   [3]      [None]      [None]
#  6                   [Rafael NADAL]   [6]   [6]   [6]      [None]      [None]
#  7               [Alexander ZVEREV]   [1]   [4]   [4]      [None]      [None]
#  8                   [David FERRER]   [7]   [3]   [7]         [7]      [None]
#  9          [Philipp KOHLSCHREIBER]   [6]   [6]   [6]         [1]      [None]
#
#    Tie-Break 3        match status    match
#  0      [None]  PLAYED & COMPLETED  MATCH 1
#  1      [None]  PLAYED & COMPLETED  MATCH 1
#  2      [None]  PLAYED & COMPLETED  MATCH 2
#  3      [None]  PLAYED & COMPLETED  MATCH 2
#  4      [None]  PLAYED & COMPLETED  MATCH 3
#  5      [None]  PLAYED & COMPLETED  MATCH 3
#  6      [None]  PLAYED & COMPLETED  MATCH 4
#  7      [None]  PLAYED & COMPLETED  MATCH 4
#  8      [None]  PLAYED & COMPLETED  MATCH 5
#  9      [None]  PLAYED & COMPLETED  MATCH 5  ,
#                      Date                                     Venue  \
#  0   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  1   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  2   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  3   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  4   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  5   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  6   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  7   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  8   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#  9   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#
#                       Surface                     Ball                   Stage  \
#  0   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  1   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  2   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  3   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  4   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  5   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  6   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  7   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  8   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#  9   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#
#                          Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
#  0                [Borna CORIC]   [6]   [7]   [6]      [None]      [None]
#  1              [Steve JOHNSON]   [4]   [6]   [3]      [None]      [None]
#  2                [Marin CILIC]   [6]   [6]   [7]      [None]      [None]
#  3             [Frances TIAFOE]   [1]   [3]   [6]      [None]      [None]
#  4     [Ivan DODIG\nMate PAVIC]   [5]   [6]   [6]      [None]      [None]
#  5  [Mike BRYAN\nRyan HARRISON]   [7]   [7]   [1]      [None]      [None]
#  6                [Marin CILIC]   [7]   [6]   [3]         [7]      [None]
#  7                [Sam QUERREY]   [6]   [7]   [6]         [2]      [None]
#  8                [Borna CORIC]   [6]   [6]   [6]         [0]      [None]
#  9             [Frances TIAFOE]   [7]   [1]   [7]         [7]      [None]
#
#    Tie-Break 3        match status    match
#  0      [None]  PLAYED & COMPLETED  MATCH 1
#  1      [None]  PLAYED & COMPLETED  MATCH 1
#  2      [None]  PLAYED & COMPLETED  MATCH 2
#  3      [None]  PLAYED & COMPLETED  MATCH 2
#  4      [None]  PLAYED & COMPLETED  MATCH 3
#  5      [None]  PLAYED & COMPLETED  MATCH 3
#  6      [None]  PLAYED & COMPLETED  MATCH 4
#  7      [None]  PLAYED & COMPLETED  MATCH 4
#  8      [None]  PLAYED & COMPLETED  MATCH 5
#  9      [None]  PLAYED & COMPLETED  MATCH 5  ]

# %%
player_results
# Out:
# [      Team Name                 Info 1                      Info 2  \
#  0        FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
#  1        FRANCE       Adrian MANNARINO  Date of birth: 29 Jun 1988
#  2        FRANCE        Richard GASQUET  Date of birth: 18 Jun 1986
#  3        FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
#  4        FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
#  5        FRANCE                Captain                Yannick NOAH
#  6   NETHERLANDS            Robin HAASE  Date of birth: 06 Apr 1987
#  7   NETHERLANDS      Tallon GRIEKSPOOR  Date of birth: 02 Jul 1996
#  8   NETHERLANDS       Thiemo DE BAKKER  Date of birth: 19 Sep 1988
#  9   NETHERLANDS       Matwe MIDDELKOOP  Date of birth: 03 Sep 1983
#  10  NETHERLANDS      Jean-Julien ROJER  Date of birth: 25 Aug 1981
#  11  NETHERLANDS                Captain               Paul HAARHUIS
#
#                    Info 3                Info 4
#  0   Singles ranking: 333  Doubles ranking: 835
#  1    Singles ranking: 22  Doubles ranking: 286
#  2    Singles ranking: 79      Doubles ranking:
#  3   Singles ranking: 251   Doubles ranking: 74
#  4       Singles ranking:   Doubles ranking: 38
#  5                    NaN                   NaN
#  6   Singles ranking: 699   Doubles ranking: 41
#  7    Singles ranking: 23  Doubles ranking: 109
#  8   Singles ranking: 710  Doubles ranking: 686
#  9       Singles ranking:   Doubles ranking: 42
#  10      Singles ranking:   Doubles ranking: 18
#  11                   NaN                   NaN  ,
#     Team Name             Info 1                      Info 2  \
#  0      JAPAN      Yuichi SUGITA  Date of birth: 18 Sep 1988
#  1      JAPAN        Taro DANIEL  Date of birth: 27 Jan 1993
#  2      JAPAN           Go SOEDA  Date of birth: 05 Sep 1984
#  3      JAPAN  Yasutaka UCHIYAMA  Date of birth: 05 Aug 1992
#  4      JAPAN      Ben MCLACHLAN  Date of birth: 10 May 1992
#  5      JAPAN            Captain            Satoshi IWABUCHI
#  6      ITALY      Fabio FOGNINI  Date of birth: 24 May 1987
#  7      ITALY      Paolo LORENZI  Date of birth: 15 Dec 1981
#  8      ITALY      Andreas SEPPI  Date of birth: 21 Feb 1984
#  9      ITALY    Thomas FABBIANO  Date of birth: 26 May 1989
#  10     ITALY     Simone BOLELLI  Date of birth: 08 Oct 1985
#  11     ITALY            Captain          Corrado BARAZZUTTI
#
#                    Info 3                Info 4
#  0   Singles ranking: 942      Doubles ranking:
#  1    Singles ranking: 78      Doubles ranking:
#  2       Singles ranking:      Doubles ranking:
#  3   Singles ranking: 301  Doubles ranking: 211
#  4       Singles ranking:   Doubles ranking: 78
#  5                    NaN                   NaN
#  6   Singles ranking: 129  Doubles ranking: 127
#  7       Singles ranking:      Doubles ranking:
#  8       Singles ranking:      Doubles ranking:
#  9       Singles ranking:      Doubles ranking:
#  10      Singles ranking:   Doubles ranking: 55
#  11                   NaN                   NaN  ,
#          Team Name                 Info 1                      Info 2  \
#  0           SPAIN    Pablo CARRENO BUSTA  Date of birth: 12 Jul 1991
#  1           SPAIN   Albert RAMOS-VINOLAS  Date of birth: 17 Jan 1988
#  2           SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
#  3           SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
#  4           SPAIN           David FERRER  Date of birth: 02 Apr 1982
#  5           SPAIN                Captain              Sergi BRUGUERA
#  6   GREAT BRITAIN            Kyle EDMUND  Date of birth: 08 Jan 1995
#  7   GREAT BRITAIN         Cameron NORRIE  Date of birth: 23 Aug 1995
#  8   GREAT BRITAIN            Liam BROADY  Date of birth: 04 Jan 1994
#  9   GREAT BRITAIN           Jamie MURRAY  Date of birth: 13 Feb 1986
#  10  GREAT BRITAIN         Dominic INGLOT  Date of birth: 06 Mar 1986
#  11  GREAT BRITAIN                Captain                  Leon SMITH
#
#                    Info 3                Info 4
#  0   Singles ranking: 603      Doubles ranking:
#  1    Singles ranking: 94      Doubles ranking:
#  2    Singles ranking: 62      Doubles ranking:
#  3   Singles ranking: 460      Doubles ranking:
#  4       Singles ranking:      Doubles ranking:
#  5                    NaN                   NaN
#  6   Singles ranking: 527      Doubles ranking:
#  7    Singles ranking: 18  Doubles ranking: 195
#  8   Singles ranking: 102  Doubles ranking: 237
#  9       Singles ranking:  Doubles ranking: 16=
#  10      Singles ranking:      Doubles ranking:
#  11                   NaN                   NaN  ,
#      Team Name              Info 1                      Info 2  \
#  0   AUSTRALIA        Nick KYRGIOS  Date of birth: 27 Apr 1995
#  1   AUSTRALIA       Matthew EBDEN  Date of birth: 26 Nov 1987
#  2   AUSTRALIA        John MILLMAN  Date of birth: 14 Jun 1989
#  3   AUSTRALIA      Alex DE MINAUR  Date of birth: 17 Feb 1999
#  4   AUSTRALIA          John PEERS  Date of birth: 25 Jul 1988
#  5   AUSTRALIA             Captain              Lleyton HEWITT
#  6     GERMANY    Alexander ZVEREV  Date of birth: 20 Apr 1997
#  7     GERMANY  Jan-Lennard STRUFF  Date of birth: 25 Apr 1990
#  8     GERMANY     Peter GOJOWCZYK  Date of birth: 15 Jul 1989
#  9     GERMANY           Tim PUETZ  Date of birth: 19 Nov 1987
#  10    GERMANY             Captain            Michael KOHLMANN
#
#                    Info 3                 Info 4
#  0       Singles ranking:       Doubles ranking:
#  1       Singles ranking:     Doubles ranking: 4
#  2   Singles ranking: 437       Doubles ranking:
#  3    Singles ranking: 12   Doubles ranking: 176
#  4       Singles ranking:    Doubles ranking: 39
#  5                    NaN                    NaN
#  6     Singles ranking: 7  Doubles ranking: 197=
#  7    Singles ranking: 25   Doubles ranking: 285
#  8   Singles ranking: 372       Doubles ranking:
#  9       Singles ranking:    Doubles ranking: 24
#  10                   NaN                    NaN  ,
#        Team Name                Info 1                      Info 2  \
#  0    KAZAKHSTAN     Mikhail KUKUSHKIN  Date of birth: 26 Dec 1987
#  1    KAZAKHSTAN          Dmitry POPKO  Date of birth: 24 Oct 1996
#  2    KAZAKHSTAN  Aleksandr NEDOVYESOV  Date of birth: 15 Feb 1987
#  3    KAZAKHSTAN       Roman KHASSANOV  Date of birth: 07 Sep 1996
#  4    KAZAKHSTAN      Timur KHABIBULIN  Date of birth: 02 Aug 1995
#  5    KAZAKHSTAN               Captain             Dias DOSKARAYEV
#  6   SWITZERLAND       Henri LAAKSONEN  Date of birth: 31 Mar 1992
#  7   SWITZERLAND         Adrian BODMER  Date of birth: 06 Mar 1995
#  8   SWITZERLAND   Marc-Andrea HUESLER  Date of birth: 24 Jun 1996
#  9   SWITZERLAND       Antoine BELLIER  Date of birth: 18 Oct 1996
#  10  SWITZERLAND        Luca MARGAROLI  Date of birth: 15 Feb 1992
#  11  SWITZERLAND               Captain               Severin LUTHI
#
#                      Info 3                 Info 4
#  0     Singles ranking: 210       Doubles ranking:
#  1     Singles ranking: 506  Doubles ranking: 903=
#  2         Singles ranking:    Doubles ranking: 44
#  3         Singles ranking:       Doubles ranking:
#  4         Singles ranking:       Doubles ranking:
#  5                      NaN                    NaN
#  6     Singles ranking: 556       Doubles ranking:
#  7   Singles ranking: 1673=       Doubles ranking:
#  8     Singles ranking: 197   Doubles ranking: 236
#  9     Singles ranking: 243   Doubles ranking: 492
#  10        Singles ranking:   Doubles ranking: 144
#  11                     NaN                    NaN  ,
#     Team Name                 Info 1                      Info 2  \
#  0                     Fabio FOGNINI  Date of birth: 24 May 1987
#  1                     Paolo LORENZI  Date of birth: 15 Dec 1981
#  2                     Andreas SEPPI  Date of birth: 21 Feb 1984
#  3                 Matteo BERRETTINI  Date of birth: 12 Apr 1996
#  4                    Simone BOLELLI  Date of birth: 08 Oct 1985
#  5                           Captain          Corrado BARAZZUTTI
#  6     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
#  7     FRANCE       Adrian MANNARINO  Date of birth: 29 Jun 1988
#  8     FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
#  9     FRANCE          Jeremy CHARDY  Date of birth: 12 Feb 1987
#  10    FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
#  11    FRANCE                Captain                Yannick NOAH
#
#                    Info 3                Info 4
#  0   Singles ranking: 129  Doubles ranking: 127
#  1       Singles ranking:      Doubles ranking:
#  2       Singles ranking:      Doubles ranking:
#  3    Singles ranking: 90      Doubles ranking:
#  4       Singles ranking:   Doubles ranking: 55
#  5                    NaN                   NaN
#  6   Singles ranking: 333  Doubles ranking: 835
#  7    Singles ranking: 22  Doubles ranking: 286
#  8   Singles ranking: 251   Doubles ranking: 74
#  9   Singles ranking: 505  Doubles ranking: 113
#  10      Singles ranking:   Doubles ranking: 38
#  11                   NaN                   NaN  ,
#     Team Name                 Info 1                      Info 2  \
#  0      SPAIN           Rafael NADAL  Date of birth: 03 Jun 1986
#  1      SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
#  2      SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
#  3      SPAIN           David FERRER  Date of birth: 02 Apr 1982
#  4      SPAIN                Captain              Sergi BRUGUERA
#  5    GERMANY       Alexander ZVEREV  Date of birth: 20 Apr 1997
#  6    GERMANY  Philipp KOHLSCHREIBER  Date of birth: 16 Oct 1983
#  7    GERMANY     Jan-Lennard STRUFF  Date of birth: 25 Apr 1990
#  8    GERMANY    Maximilian MARTERER  Date of birth: 15 Jun 1995
#  9    GERMANY              Tim PUETZ  Date of birth: 19 Nov 1987
#  10   GERMANY                Captain            Michael KOHLMANN
#
#                    Info 3                 Info 4
#  0   Singles ranking: 664       Doubles ranking:
#  1    Singles ranking: 62       Doubles ranking:
#  2   Singles ranking: 460       Doubles ranking:
#  3       Singles ranking:       Doubles ranking:
#  4                    NaN                    NaN
#  5     Singles ranking: 7  Doubles ranking: 197=
#  6       Singles ranking:       Doubles ranking:
#  7    Singles ranking: 25   Doubles ranking: 285
#  8   Singles ranking: 100   Doubles ranking: 715
#  9       Singles ranking:    Doubles ranking: 24
#  10                   NaN                    NaN  ,
#       Team Name                Info 1                      Info 2  \
#  0      CROATIA           Marin CILIC  Date of birth: 28 Sep 1988
#  1      CROATIA           Borna CORIC  Date of birth: 14 Nov 1996
#  2      CROATIA        Viktor GALOVIC  Date of birth: 19 Sep 1990
#  3      CROATIA            Ivan DODIG  Date of birth: 02 Jan 1985
#  4      CROATIA         Nikola MEKTIC  Date of birth: 24 Dec 1988
#  5      CROATIA               Captain               Zeljko KRAJAN
#  6   KAZAKHSTAN     Mikhail KUKUSHKIN  Date of birth: 26 Dec 1987
#  7   KAZAKHSTAN  Aleksandr NEDOVYESOV  Date of birth: 15 Feb 1987
#  8   KAZAKHSTAN          Dmitry POPKO  Date of birth: 24 Oct 1996
#  9   KAZAKHSTAN        Denis YEVSEYEV  Date of birth: 22 May 1993
#  10  KAZAKHSTAN      Timur KHABIBULIN  Date of birth: 02 Aug 1995
#  11  KAZAKHSTAN               Captain             Dias DOSKARAYEV
#
#                    Info 3                 Info 4
#  0   Singles ranking: 666       Doubles ranking:
#  1    Singles ranking: 37       Doubles ranking:
#  2       Singles ranking:       Doubles ranking:
#  3       Singles ranking:     Doubles ranking: 2
#  4       Singles ranking:    Doubles ranking: 43
#  5                    NaN                    NaN
#  6   Singles ranking: 210       Doubles ranking:
#  7       Singles ranking:    Doubles ranking: 44
#  8   Singles ranking: 506  Doubles ranking: 903=
#  9   Singles ranking: 228   Doubles ranking: 540
#  10      Singles ranking:       Doubles ranking:
#  11                   NaN                    NaN  ,
#     Team Name           Info 1                      Info 2  \
#  0        USA       John ISNER  Date of birth: 26 Apr 1985
#  1        USA      Sam QUERREY  Date of birth: 07 Oct 1987
#  2        USA        Jack SOCK  Date of birth: 24 Sep 1992
#  3        USA    Steve JOHNSON  Date of birth: 24 Dec 1989
#  4        USA    Ryan HARRISON  Date of birth: 07 May 1992
#  5        USA          Captain                 Jim COURIER
#  6    BELGIUM  Ruben BEMELMANS  Date of birth: 14 Jan 1988
#  7    BELGIUM   Joris DE LOORE  Date of birth: 21 Apr 1993
#  8    BELGIUM     Sander GILLE  Date of birth: 15 Jan 1991
#  9    BELGIUM    Joran VLIEGEN  Date of birth: 07 Jul 1993
#  10   BELGIUM          Captain             Johan VAN HERCK
#
#                    Info 3                 Info 4
#  0   Singles ranking: 175   Doubles ranking: 194
#  1       Singles ranking:       Doubles ranking:
#  2   Singles ranking: 665   Doubles ranking: 192
#  3   Singles ranking: 226       Doubles ranking:
#  4   Singles ranking: 828   Doubles ranking: 834
#  5                    NaN                    NaN
#  6       Singles ranking:       Doubles ranking:
#  7   Singles ranking: 145  Doubles ranking: 854=
#  8       Singles ranking:   Doubles ranking: 25=
#  9       Singles ranking:   Doubles ranking: 25=
#  10                   NaN                    NaN  ,
#     Team Name                 Info 1                      Info 2  \
#  0                     Lucas POUILLE  Date of birth: 23 Feb 1994
#  1                   Richard GASQUET  Date of birth: 18 Jun 1986
#  2                      Benoit PAIRE  Date of birth: 08 May 1989
#  3                  Julien BENNETEAU  Date of birth: 20 Dec 1981
#  4                     Nicolas MAHUT  Date of birth: 21 Jan 1982
#  5                           Captain                Yannick NOAH
#  6      SPAIN    Pablo CARRENO BUSTA  Date of birth: 12 Jul 1991
#  7      SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
#  8      SPAIN   Albert RAMOS-VINOLAS  Date of birth: 17 Jan 1988
#  9      SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
#  10     SPAIN      Marcel GRANOLLERS  Date of birth: 12 Apr 1986
#  11     SPAIN                Captain              Sergi BRUGUERA
#
#                    Info 3                Info 4
#  0   Singles ranking: 333  Doubles ranking: 835
#  1    Singles ranking: 79      Doubles ranking:
#  2   Singles ranking: 126  Doubles ranking: 526
#  3       Singles ranking:      Doubles ranking:
#  4       Singles ranking:   Doubles ranking: 38
#  5                    NaN                   NaN
#  6   Singles ranking: 603      Doubles ranking:
#  7    Singles ranking: 62      Doubles ranking:
#  8    Singles ranking: 94      Doubles ranking:
#  9   Singles ranking: 460      Doubles ranking:
#  10      Singles ranking:   Doubles ranking: 10
#  11                   NaN                   NaN  ,
#     Team Name          Info 1                      Info 2  \
#  0    CROATIA     Marin CILIC  Date of birth: 28 Sep 1988
#  1    CROATIA     Borna CORIC  Date of birth: 14 Nov 1996
#  2    CROATIA   Franko SKUGOR  Date of birth: 20 Sep 1987
#  3    CROATIA      Mate PAVIC  Date of birth: 04 Jul 1993
#  4    CROATIA      Ivan DODIG  Date of birth: 02 Jan 1985
#  5    CROATIA         Captain               Zeljko KRAJAN
#  6        USA   Steve JOHNSON  Date of birth: 24 Dec 1989
#  7        USA  Frances TIAFOE  Date of birth: 20 Jan 1998
#  8        USA   Ryan HARRISON  Date of birth: 07 May 1992
#  9        USA     Sam QUERREY  Date of birth: 07 Oct 1987
#  10       USA      Mike BRYAN  Date of birth: 29 Apr 1978
#  11       USA         Captain                 Jim COURIER
#
#                    Info 3                Info 4
#  0   Singles ranking: 666      Doubles ranking:
#  1    Singles ranking: 37      Doubles ranking:
#  2       Singles ranking:  Doubles ranking: 169
#  3       Singles ranking:   Doubles ranking: 32
#  4       Singles ranking:    Doubles ranking: 2
#  5                    NaN                   NaN
#  6   Singles ranking: 226      Doubles ranking:
#  7    Singles ranking: 16  Doubles ranking: 196
#  8   Singles ranking: 828  Doubles ranking: 834
#  9       Singles ranking:      Doubles ranking:
#  10      Singles ranking:      Doubles ranking:
#  11                   NaN                   NaN  ,
#     Team Name                 Info 1                      Info 2  \
#  0     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
#  1     FRANCE          Jeremy CHARDY  Date of birth: 12 Feb 1987
#  2     FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
#  3     FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
#  4     FRANCE     Jo-Wilfried TSONGA  Date of birth: 17 Apr 1985
#  5     FRANCE                Captain                Yannick NOAH
#  6    CROATIA            Marin CILIC  Date of birth: 28 Sep 1988
#  7    CROATIA            Borna CORIC  Date of birth: 14 Nov 1996
#  8    CROATIA          Franko SKUGOR  Date of birth: 20 Sep 1987
#  9    CROATIA             Mate PAVIC  Date of birth: 04 Jul 1993
#  10   CROATIA             Ivan DODIG  Date of birth: 02 Jan 1985
#  11   CROATIA                Captain               Zeljko KRAJAN
#
#                    Info 3                Info 4
#  0   Singles ranking: 333  Doubles ranking: 835
#  1   Singles ranking: 505  Doubles ranking: 113
#  2   Singles ranking: 251   Doubles ranking: 74
#  3       Singles ranking:   Doubles ranking: 38
#  4       Singles ranking:      Doubles ranking:
#  5                    NaN                   NaN
#  6   Singles ranking: 666      Doubles ranking:
#  7    Singles ranking: 37      Doubles ranking:
#  8       Singles ranking:  Doubles ranking: 169
#  9       Singles ranking:   Doubles ranking: 32
#  10      Singles ranking:    Doubles ranking: 2
#  11                   NaN                   NaN  ]

# %% [markdown]
# # Create and clean dataframe

# %%
def to_df(links):
    # Initialize ChromeOptions with headless mode
    chrome_options = Options()
    chrome_options.add_argument("--headless")

    # Initialize Selenium WebDriver with the provided executable path and headless option
    driver = webdriver.Chrome(executable_path="C:/Users/ALESSANDRO/Downloads/chromedriver.exe", options=chrome_options)

    try:
        # Create empty lists to store the results
        match_results = []
        player_results = []

        for link in links:
            # Apply the functions to extract match and player data
            matches_df = extract_matches_df(link)
            players_df = extract_players_df(link)

            if matches_df is not None:
                match_results.append(matches_df)
            if players_df is not None:
                player_results.append(players_df)

        # Close the Selenium WebDriver
        driver.quit()

        # Create DataFrames from the lists
        matches_df = pd.concat(match_results, ignore_index=True)
        players_df = pd.concat(player_results, ignore_index=True)

        return matches_df, players_df

    except Exception as e:
        print("Error:", str(e))
        driver.quit()

    return None, None  # Return None if there was an error

# %% [markdown]
# # Main function to scrape data for a single year and save the data in a dataframe format

# %%
# Usage example:
# URL of the webpage
url = "https://www.daviscup.com/en/draws-results/historic-format/world-group.aspx"

# Navigate to the webpage
driver = webdriver.Chrome(executable_path="C:/Users/ALESSANDRO/Downloads/chromedriver.exe")
driver.get(url)

try:
    # Wait for the page to load
    driver.implicitly_wait(10)  # You can adjust the waiting time as needed

    # Find all links with class "tie-link" within the tables
    tie_links = driver.find_elements(By.CSS_SELECTOR, "table.tie.ng-scope a.tie-link")

    # Initialize a list to store the extracted links
    links = []

    # Extract the links
    for link in tie_links:
        href = link.get_attribute("href")
        links.append(href)

    # Call the function to scrape and transform the data
    matches_df, players_df = to_df(links)

finally:
    driver.quit()
# Out:
# C:\Users\ALESSANDRO\AppData\Local\Temp\ipykernel_19196\2424561579.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/ALESSANDRO/Downloads/chromedriver.exe")
# C:\Users\ALESSANDRO\AppData\Local\Temp\ipykernel_19196\254483608.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/ALESSANDRO/Downloads/chromedriver.exe", options=chrome_options)
# Loaded!
# {'Player': ['Adrian MANNARINO'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['3'], 'Tie-Break 1': ['4'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Thiemo DE BAKKER'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Richard GASQUET'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Robin HAASE'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Pierre-Hugues HERBERT\nNicolas MAHUT'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['8'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Robin HAASE\nJean-Julien ROJER'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['7'], 'Tie-Break 1': ['6'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Adrian MANNARINO'], 'Set 1': ['4'], 'Set 2': ['7'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Robin HAASE'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['5'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                  Venue  \
# 0   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 1   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 2   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 3   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 4   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 5   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 6   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 7   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 8   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
# 9   02 Feb - 04 Feb 2018   Halle Olympique, Albertville, France
#
#                                Surface               Ball  \
# 0   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 1   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 2   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 3   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 4   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 5   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 6   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 7   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 8   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 9   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#
#                     Stage                                  Player Set 1 Set 2  \
# 0  WORLD GROUP  1ST ROUND                      [Adrian MANNARINO]   [6]   [3]
# 1  WORLD GROUP  1ST ROUND                      [Thiemo DE BAKKER]   [7]   [6]
# 2  WORLD GROUP  1ST ROUND                       [Richard GASQUET]   [6]   [7]
# 3  WORLD GROUP  1ST ROUND                           [Robin HAASE]   [4]   [6]
# 4  WORLD GROUP  1ST ROUND  [Pierre-Hugues HERBERT\nNicolas MAHUT]   [7]   [6]
# 5  WORLD GROUP  1ST ROUND        [Robin HAASE\nJean-Julien ROJER]   [6]   [3]
# 6  WORLD GROUP  1ST ROUND                      [Adrian MANNARINO]   [4]   [7]
# 7  WORLD GROUP  1ST ROUND                           [Robin HAASE]   [6]   [6]
# 8  WORLD GROUP  1ST ROUND                                      []    []    []
# 9  WORLD GROUP  1ST ROUND                                      []    []    []
#
#   Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
# 0   [3]         [4]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1   [6]         [7]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2   [3]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4   [6]         [8]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5   [7]         [6]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7   [5]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8    []          []          []          []          NOT PLAYED  MATCH 5
# 9    []          []          []          []          NOT PLAYED  MATCH 5
# Loaded!
#       Team Name                 Info 1                      Info 2  \
# 0        FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 1        FRANCE       Adrian MANNARINO  Date of birth: 29 Jun 1988
# 2        FRANCE        Richard GASQUET  Date of birth: 18 Jun 1986
# 3        FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
# 4        FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 5        FRANCE                Captain                Yannick NOAH
# 6   NETHERLANDS            Robin HAASE  Date of birth: 06 Apr 1987
# 7   NETHERLANDS      Tallon GRIEKSPOOR  Date of birth: 02 Jul 1996
# 8   NETHERLANDS       Thiemo DE BAKKER  Date of birth: 19 Sep 1988
# 9   NETHERLANDS       Matwe MIDDELKOOP  Date of birth: 03 Sep 1983
# 10  NETHERLANDS      Jean-Julien ROJER  Date of birth: 25 Aug 1981
# 11  NETHERLANDS                Captain               Paul HAARHUIS
#
#                   Info 3                Info 4
# 0   Singles ranking: 333  Doubles ranking: 835
# 1    Singles ranking: 22  Doubles ranking: 286
# 2    Singles ranking: 79      Doubles ranking:
# 3   Singles ranking: 251   Doubles ranking: 74
# 4       Singles ranking:   Doubles ranking: 38
# 5                    NaN                   NaN
# 6   Singles ranking: 699   Doubles ranking: 41
# 7    Singles ranking: 23  Doubles ranking: 109
# 8   Singles ranking: 710  Doubles ranking: 686
# 9       Singles ranking:   Doubles ranking: 42
# 10      Singles ranking:   Doubles ranking: 18
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Taro DANIEL'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Fabio FOGNINI'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Yuichi SUGITA'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Andreas SEPPI'], 'Set 1': ['6'], 'Set 2': ['2'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ben MCLACHLAN\nYasutaka UCHIYAMA'], 'Set 1': ['5'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Simone BOLELLI\nFabio FOGNINI'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Yuichi SUGITA'], 'Set 1': ['6'], 'Set 2': ['1'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Fabio FOGNINI'], 'Set 1': ['3'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                  Venue  \
# 0   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 1   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 2   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 3   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 4   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 5   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 6   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 7   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 8   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
# 9   02 Feb - 04 Feb 2018   Morioka Takaya Arena, Morioka, Japan
#
#                         Surface Court Pace Rating     Ball  \
# 0   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 1   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 2   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 3   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 4   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 5   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 6   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 7   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 8   Hard - GreenSet Pro, Indoor              Fast   Srixon
# 9   Hard - GreenSet Pro, Indoor              Fast   Srixon
#
#                     Stage                              Player Set 1 Set 2  \
# 0  WORLD GROUP  1ST ROUND                       [Taro DANIEL]   [4]   [6]
# 1  WORLD GROUP  1ST ROUND                     [Fabio FOGNINI]   [6]   [3]
# 2  WORLD GROUP  1ST ROUND                     [Yuichi SUGITA]   [4]   [6]
# 3  WORLD GROUP  1ST ROUND                     [Andreas SEPPI]   [6]   [2]
# 4  WORLD GROUP  1ST ROUND  [Ben MCLACHLAN\nYasutaka UCHIYAMA]   [5]   [7]
# 5  WORLD GROUP  1ST ROUND     [Simone BOLELLI\nFabio FOGNINI]   [7]   [6]
# 6  WORLD GROUP  1ST ROUND                     [Yuichi SUGITA]   [6]   [1]
# 7  WORLD GROUP  1ST ROUND                     [Fabio FOGNINI]   [3]   [6]
# 8  WORLD GROUP  1ST ROUND                                  []    []    []
# 9  WORLD GROUP  1ST ROUND                                  []    []    []
#
#   Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
# 0   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7   [3]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8    []          []          []          []          NOT PLAYED  MATCH 5
# 9    []          []          []          []          NOT PLAYED  MATCH 5
# Loaded!
#    Team Name             Info 1                      Info 2  \
# 0      JAPAN      Yuichi SUGITA  Date of birth: 18 Sep 1988
# 1      JAPAN        Taro DANIEL  Date of birth: 27 Jan 1993
# 2      JAPAN           Go SOEDA  Date of birth: 05 Sep 1984
# 3      JAPAN  Yasutaka UCHIYAMA  Date of birth: 05 Aug 1992
# 4      JAPAN      Ben MCLACHLAN  Date of birth: 10 May 1992
# 5      JAPAN            Captain            Satoshi IWABUCHI
# 6      ITALY      Fabio FOGNINI  Date of birth: 24 May 1987
# 7      ITALY      Paolo LORENZI  Date of birth: 15 Dec 1981
# 8      ITALY      Andreas SEPPI  Date of birth: 21 Feb 1984
# 9      ITALY    Thomas FABBIANO  Date of birth: 26 May 1989
# 10     ITALY     Simone BOLELLI  Date of birth: 08 Oct 1985
# 11     ITALY            Captain          Corrado BARAZZUTTI
#
#                   Info 3                Info 4
# 0   Singles ranking: 942      Doubles ranking:
# 1    Singles ranking: 78      Doubles ranking:
# 2       Singles ranking:      Doubles ranking:
# 3   Singles ranking: 301  Doubles ranking: 211
# 4       Singles ranking:   Doubles ranking: 78
# 5                    NaN                   NaN
# 6   Singles ranking: 129  Doubles ranking: 127
# 7       Singles ranking:      Doubles ranking:
# 8       Singles ranking:      Doubles ranking:
# 9       Singles ranking:      Doubles ranking:
# 10      Singles ranking:   Doubles ranking: 55
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Albert RAMOS-VINOLAS'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Liam BROADY'], 'Set 1': ['3'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Roberto BAUTISTA AGUT'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Cameron NORRIE'], 'Set 1': ['4'], 'Set 2': ['3'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Pablo CARRENO BUSTA\nFeliciano LOPEZ'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Dominic INGLOT\nJamie MURRAY'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Albert RAMOS-VINOLAS'], 'Set 1': ['7'], 'Set 2': ['2'], 'Set 3': ['7'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Cameron NORRIE'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['4'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                          Venue  \
# 0   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 1   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 2   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 3   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 4   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 5   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 6   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 7   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 8   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
# 9   02 Feb - 04 Feb 2018   Club de Tenis Puente Romano, Marbella, Spain
#
#                  Surface       Ball                   Stage  \
# 0   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 1   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 2   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 3   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 4   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 5   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 6   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 7   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 8   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
# 9   Clay - Clay, Outdoor   Head ATP  WORLD GROUP  1ST ROUND
#
#                                    Player Set 1 Set 2 Set 3 Tie-Break 1  \
# 0                  [Albert RAMOS-VINOLAS]   [6]   [6]   [7]      [None]
# 1                           [Liam BROADY]   [3]   [4]   [6]      [None]
# 2                 [Roberto BAUTISTA AGUT]   [6]   [6]   [3]      [None]
# 3                        [Cameron NORRIE]   [4]   [3]   [6]      [None]
# 4  [Pablo CARRENO BUSTA\nFeliciano LOPEZ]   [6]   [6]   [7]      [None]
# 5          [Dominic INGLOT\nJamie MURRAY]   [4]   [4]   [6]      [None]
# 6                  [Albert RAMOS-VINOLAS]   [7]   [2]   [7]         [7]
# 7                        [Cameron NORRIE]   [6]   [6]   [6]         [4]
# 8                                      []    []    []    []          []
# 9                                      []    []    []    []          []
#
#   Tie-Break 2 Tie-Break 3        match status    match
# 0      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8          []          []          NOT PLAYED  MATCH 5
# 9          []          []          NOT PLAYED  MATCH 5
# Loaded!
#         Team Name                 Info 1                      Info 2  \
# 0           SPAIN    Pablo CARRENO BUSTA  Date of birth: 12 Jul 1991
# 1           SPAIN   Albert RAMOS-VINOLAS  Date of birth: 17 Jan 1988
# 2           SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
# 3           SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
# 4           SPAIN           David FERRER  Date of birth: 02 Apr 1982
# 5           SPAIN                Captain              Sergi BRUGUERA
# 6   GREAT BRITAIN            Kyle EDMUND  Date of birth: 08 Jan 1995
# 7   GREAT BRITAIN         Cameron NORRIE  Date of birth: 23 Aug 1995
# 8   GREAT BRITAIN            Liam BROADY  Date of birth: 04 Jan 1994
# 9   GREAT BRITAIN           Jamie MURRAY  Date of birth: 13 Feb 1986
# 10  GREAT BRITAIN         Dominic INGLOT  Date of birth: 06 Mar 1986
# 11  GREAT BRITAIN                Captain                  Leon SMITH
#
#                   Info 3                Info 4
# 0   Singles ranking: 603      Doubles ranking:
# 1    Singles ranking: 94      Doubles ranking:
# 2    Singles ranking: 62      Doubles ranking:
# 3   Singles ranking: 460      Doubles ranking:
# 4       Singles ranking:      Doubles ranking:
# 5                    NaN                   NaN
# 6   Singles ranking: 527      Doubles ranking:
# 7    Singles ranking: 18  Doubles ranking: 195
# 8   Singles ranking: 102  Doubles ranking: 237
# 9       Singles ranking:  Doubles ranking: 16=
# 10      Singles ranking:      Doubles ranking:
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Alex DE MINAUR'], 'Set 1': ['5'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['7'], 'Set 2': ['4'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Nick KYRGIOS'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Jan-Lennard STRUFF'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Matthew EBDEN\nJohn PEERS'], 'Set 1': ['4'], 'Set 2': ['7'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Tim PUETZ\nJan-Lennard STRUFF'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Nick KYRGIOS'], 'Set 1': ['2'], 'Set 2': ['6'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                   Venue  \
# 0   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 1   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 2   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 3   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 4   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 5   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 6   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 7   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 8   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
# 9   02 Feb - 04 Feb 2018   Pat Rafter Arena, Brisbane, Australia
#
#                                   Surface Court Pace Rating  \
# 0   Hard - Plexicushion Prestige, Outdoor              Fast
# 1   Hard - Plexicushion Prestige, Outdoor              Fast
# 2   Hard - Plexicushion Prestige, Outdoor              Fast
# 3   Hard - Plexicushion Prestige, Outdoor              Fast
# 4   Hard - Plexicushion Prestige, Outdoor              Fast
# 5   Hard - Plexicushion Prestige, Outdoor              Fast
# 6   Hard - Plexicushion Prestige, Outdoor              Fast
# 7   Hard - Plexicushion Prestige, Outdoor              Fast
# 8   Hard - Plexicushion Prestige, Outdoor              Fast
# 9   Hard - Plexicushion Prestige, Outdoor              Fast
#
#                       Ball                   Stage  \
# 0   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 1   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 2   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 3   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 4   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 5   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 6   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 7   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 8   Wilson Australian Open  WORLD GROUP  1ST ROUND
# 9   Wilson Australian Open  WORLD GROUP  1ST ROUND
#
#                             Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
# 0                 [Alex DE MINAUR]   [5]   [6]   [6]      [None]      [None]
# 1               [Alexander ZVEREV]   [7]   [4]   [4]      [None]      [None]
# 2                   [Nick KYRGIOS]   [6]   [6]   [6]      [None]      [None]
# 3             [Jan-Lennard STRUFF]   [4]   [4]   [4]      [None]      [None]
# 4      [Matthew EBDEN\nJohn PEERS]   [4]   [7]   [2]      [None]      [None]
# 5  [Tim PUETZ\nJan-Lennard STRUFF]   [6]   [6]   [6]      [None]      [None]
# 6                   [Nick KYRGIOS]   [2]   [6]   [2]      [None]      [None]
# 7               [Alexander ZVEREV]   [6]   [7]   [6]      [None]      [None]
# 8                               []    []    []    []          []          []
# 9                               []    []    []    []          []          []
#
#   Tie-Break 3        match status    match
# 0      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]  PLAYED & COMPLETED  MATCH 4
# 8          []          NOT PLAYED  MATCH 5
# 9          []          NOT PLAYED  MATCH 5
# Loaded!
#     Team Name              Info 1                      Info 2  \
# 0   AUSTRALIA        Nick KYRGIOS  Date of birth: 27 Apr 1995
# 1   AUSTRALIA       Matthew EBDEN  Date of birth: 26 Nov 1987
# 2   AUSTRALIA        John MILLMAN  Date of birth: 14 Jun 1989
# 3   AUSTRALIA      Alex DE MINAUR  Date of birth: 17 Feb 1999
# 4   AUSTRALIA          John PEERS  Date of birth: 25 Jul 1988
# 5   AUSTRALIA             Captain              Lleyton HEWITT
# 6     GERMANY    Alexander ZVEREV  Date of birth: 20 Apr 1997
# 7     GERMANY  Jan-Lennard STRUFF  Date of birth: 25 Apr 1990
# 8     GERMANY     Peter GOJOWCZYK  Date of birth: 15 Jul 1989
# 9     GERMANY           Tim PUETZ  Date of birth: 19 Nov 1987
# 10    GERMANY             Captain            Michael KOHLMANN
#
#                   Info 3                 Info 4
# 0       Singles ranking:       Doubles ranking:
# 1       Singles ranking:     Doubles ranking: 4
# 2   Singles ranking: 437       Doubles ranking:
# 3    Singles ranking: 12   Doubles ranking: 176
# 4       Singles ranking:    Doubles ranking: 39
# 5                    NaN                    NaN
# 6     Singles ranking: 7  Doubles ranking: 197=
# 7    Singles ranking: 25   Doubles ranking: 285
# 8   Singles ranking: 372       Doubles ranking:
# 9       Singles ranking:    Doubles ranking: 24
# 10                   NaN                    NaN
# Loaded!
# {'Player': ['Dmitry POPKO'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Henri LAAKSONEN'], 'Set 1': ['2'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Mikhail KUKUSHKIN'], 'Set 1': ['3'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Adrian BODMER'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Timur KHABIBULIN\nAleksandr NEDOVYESOV'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marc-Andrea HUESLER\nLuca MARGAROLI'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Error: list index out of range
# Loaded!
#       Team Name                Info 1                      Info 2  \
# 0    KAZAKHSTAN     Mikhail KUKUSHKIN  Date of birth: 26 Dec 1987
# 1    KAZAKHSTAN          Dmitry POPKO  Date of birth: 24 Oct 1996
# 2    KAZAKHSTAN  Aleksandr NEDOVYESOV  Date of birth: 15 Feb 1987
# 3    KAZAKHSTAN       Roman KHASSANOV  Date of birth: 07 Sep 1996
# 4    KAZAKHSTAN      Timur KHABIBULIN  Date of birth: 02 Aug 1995
# 5    KAZAKHSTAN               Captain             Dias DOSKARAYEV
# 6   SWITZERLAND       Henri LAAKSONEN  Date of birth: 31 Mar 1992
# 7   SWITZERLAND         Adrian BODMER  Date of birth: 06 Mar 1995
# 8   SWITZERLAND   Marc-Andrea HUESLER  Date of birth: 24 Jun 1996
# 9   SWITZERLAND       Antoine BELLIER  Date of birth: 18 Oct 1996
# 10  SWITZERLAND        Luca MARGAROLI  Date of birth: 15 Feb 1992
# 11  SWITZERLAND               Captain               Severin LUTHI
#
#                     Info 3                 Info 4
# 0     Singles ranking: 210       Doubles ranking:
# 1     Singles ranking: 506  Doubles ranking: 903=
# 2         Singles ranking:    Doubles ranking: 44
# 3         Singles ranking:       Doubles ranking:
# 4         Singles ranking:       Doubles ranking:
# 5                      NaN                    NaN
# 6     Singles ranking: 556       Doubles ranking:
# 7   Singles ranking: 1673=       Doubles ranking:
# 8     Singles ranking: 197   Doubles ranking: 236
# 9     Singles ranking: 243   Doubles ranking: 492
# 10        Singles ranking:   Doubles ranking: 144
# 11                     NaN                    NaN
# Loaded!
# {'Player': ['Borna CORIC'], 'Set 1': ['3'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Vasek POSPISIL'], 'Set 1': ['6'], 'Set 2': ['2'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Viktor GALOVIC'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Denis SHAPOVALOV'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marin CILIC\nIvan DODIG'], 'Set 1': ['2'], 'Set 2': ['3'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Daniel NESTOR\nVasek POSPISIL'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Borna CORIC'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Denis SHAPOVALOV'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                           Venue  \
# 0   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 1   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 2   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 3   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 4   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 5   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 6   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 7   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 8   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
# 9   02 Feb - 04 Feb 2018   Sportska Dvorana Gradski Vrt, Osijek, Croatia
#
#                 Surface                     Ball                   Stage  \
# 0   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 1   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 2   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 3   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 4   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 5   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 6   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 7   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 8   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
# 9   Clay - Clay, Indoor   Dunlop Fort Clay Court  WORLD GROUP  1ST ROUND
#
#                             Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
# 0                    [Borna CORIC]   [3]   [6]   [6]      [None]      [None]
# 1                 [Vasek POSPISIL]   [6]   [2]   [3]      [None]      [None]
# 2                 [Viktor GALOVIC]   [4]   [4]   [2]      [None]      [None]
# 3               [Denis SHAPOVALOV]   [6]   [6]   [6]      [None]      [None]
# 4        [Marin CILIC\nIvan DODIG]   [2]   [3]   [6]      [None]      [None]
# 5  [Daniel NESTOR\nVasek POSPISIL]   [6]   [6]   [4]      [None]      [None]
# 6                    [Borna CORIC]   [6]   [6]   [6]      [None]      [None]
# 7               [Denis SHAPOVALOV]   [4]   [4]   [4]      [None]      [None]
# 8                               []    []    []    []          []          []
# 9                               []    []    []    []          []          []
#
#   Tie-Break 3        match status    match
# 0      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]  PLAYED & COMPLETED  MATCH 4
# 8          []          NOT PLAYED  MATCH 5
# 9          []          NOT PLAYED  MATCH 5
# Loaded!
#    Team Name            Info 1                      Info 2  \
# 0    CROATIA       Marin CILIC  Date of birth: 28 Sep 1988
# 1    CROATIA       Borna CORIC  Date of birth: 14 Nov 1996
# 2    CROATIA    Viktor GALOVIC  Date of birth: 19 Sep 1990
# 3    CROATIA     Franko SKUGOR  Date of birth: 20 Sep 1987
# 4    CROATIA        Ivan DODIG  Date of birth: 02 Jan 1985
# 5    CROATIA           Captain               Zeljko KRAJAN
# 6     CANADA  Denis SHAPOVALOV  Date of birth: 15 Apr 1999
# 7     CANADA    Vasek POSPISIL  Date of birth: 23 Jun 1990
# 8     CANADA    Peter POLANSKY  Date of birth: 15 Jun 1988
# 9     CANADA    Frank DANCEVIC  Date of birth: 26 Sep 1984
# 10    CANADA     Daniel NESTOR  Date of birth: 04 Sep 1972
# 11    CANADA           Captain              Frank DANCEVIC
#
#                   Info 3                 Info 4
# 0   Singles ranking: 666       Doubles ranking:
# 1    Singles ranking: 37       Doubles ranking:
# 2       Singles ranking:       Doubles ranking:
# 3       Singles ranking:   Doubles ranking: 169
# 4       Singles ranking:     Doubles ranking: 2
# 5                    NaN                    NaN
# 6   Singles ranking: 103   Doubles ranking: 193
# 7   Singles ranking: 300  Doubles ranking: 572=
# 8       Singles ranking:       Doubles ranking:
# 9       Singles ranking:       Doubles ranking:
# 10      Singles ranking:       Doubles ranking:
# 11                   NaN                    NaN
# Loaded!
# {'Player': ['Laslo DJERE'], 'Set 1': ['7'], 'Set 2': ['2'], 'Set 3': ['5'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Sam QUERREY'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': ['4'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Dusan LAJOVIC'], 'Set 1': ['4'], 'Set 2': ['7'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['John ISNER'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Nikola MILOJEVIC\nMiljan ZEKIC'], 'Set 1': ['7'], 'Set 2': ['2'], 'Set 3': ['5'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ryan HARRISON\nSteve JOHNSON'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': ['3'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Error: list index out of range
# Loaded!
#    Team Name            Info 1                      Info 2  \
# 0     SERBIA     Dusan LAJOVIC  Date of birth: 30 Jun 1990
# 1     SERBIA       Laslo DJERE  Date of birth: 02 Jun 1995
# 2     SERBIA  Nikola MILOJEVIC  Date of birth: 19 Jun 1995
# 3     SERBIA      Pedja KRSTIN  Date of birth: 03 Sep 1994
# 4     SERBIA      Miljan ZEKIC  Date of birth: 12 Jul 1988
# 5     SERBIA           Captain              Nenad ZIMONJIC
# 6        USA       Sam QUERREY  Date of birth: 07 Oct 1987
# 7        USA        John ISNER  Date of birth: 26 Apr 1985
# 8        USA     Ryan HARRISON  Date of birth: 07 May 1992
# 9        USA     Steve JOHNSON  Date of birth: 24 Dec 1989
# 10       USA           Captain                 Jim COURIER
#
#                    Info 3                 Info 4
# 0     Singles ranking: 46  Doubles ranking: 847=
# 1     Singles ranking: 33  Doubles ranking: 572=
# 2    Singles ranking: 584       Doubles ranking:
# 3   Singles ranking: 1356       Doubles ranking:
# 4    Singles ranking: 404   Doubles ranking: 839
# 5                     NaN                    NaN
# 6        Singles ranking:       Doubles ranking:
# 7    Singles ranking: 175   Doubles ranking: 194
# 8    Singles ranking: 828   Doubles ranking: 834
# 9    Singles ranking: 226       Doubles ranking:
# 10                    NaN                    NaN
# Loaded!
# Error: list index out of range
# Loaded!
#    Team Name            Info 1                      Info 2  \
# 0    BELGIUM      David GOFFIN  Date of birth: 07 Dec 1990
# 1    BELGIUM   Ruben BEMELMANS  Date of birth: 14 Jan 1988
# 2    BELGIUM    Julien CAGNINA  Date of birth: 04 Jun 1994
# 3    BELGIUM    Joris DE LOORE  Date of birth: 21 Apr 1993
# 4    BELGIUM           Captain             Johan VAN HERCK
# 5    HUNGARY  Marton FUCSOVICS  Date of birth: 08 Feb 1992
# 6    HUNGARY     Attila BALAZS  Date of birth: 27 Sep 1988
# 7    HUNGARY     Zsombor PIROS  Date of birth: 13 Oct 1999
# 8    HUNGARY      Mate VALKUSZ  Date of birth: 13 Aug 1998
# 9    HUNGARY      Gabor BORSOS  Date of birth: 30 Jun 1991
# 10   HUNGARY           Captain                 Gabor KOVES
#
#                    Info 3                  Info 4
# 0    Singles ranking: 105   Doubles ranking: 845=
# 1        Singles ranking:        Doubles ranking:
# 2        Singles ranking:        Doubles ranking:
# 3    Singles ranking: 145   Doubles ranking: 854=
# 4                     NaN                     NaN
# 5     Singles ranking: 53        Doubles ranking:
# 6   Singles ranking: 1029        Doubles ranking:
# 7    Singles ranking: 123        Doubles ranking:
# 8    Singles ranking: 216        Doubles ranking:
# 9        Singles ranking:  Doubles ranking: 1628=
# 10                    NaN                     NaN
# Loaded!
# {'Player': ['Andreas SEPPI'], 'Set 1': ['3'], 'Set 2': ['2'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Lucas POUILLE'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Fabio FOGNINI'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['6'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Jeremy CHARDY'], 'Set 1': ['7'], 'Set 2': ['2'], 'Set 3': ['2'], 'Tie-Break 1': ['8'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Simone BOLELLI\nFabio FOGNINI'], 'Set 1': ['4'], 'Set 2': ['3'], 'Set 3': ['1'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Pierre-Hugues HERBERT\nNicolas MAHUT'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Fabio FOGNINI'], 'Set 1': ['6'], 'Set 2': ['1'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Lucas POUILLE'], 'Set 1': ['2'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                 Venue  \
# 0   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 1   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 2   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 3   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 4   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 5   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 6   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 7   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 8   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
# 9   06 Apr - 08 Apr 2018   Valletta Cambiaso ASD, Genoa, Italy
#
#                      Surface                     Ball  \
# 0   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 1   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 2   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 3   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 4   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 5   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 6   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 7   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 8   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 9   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
#
#                        Stage                                  Player Set 1  \
# 0  WORLD GROUP  QUARTERFINAL                         [Andreas SEPPI]   [3]
# 1  WORLD GROUP  QUARTERFINAL                         [Lucas POUILLE]   [6]
# 2  WORLD GROUP  QUARTERFINAL                         [Fabio FOGNINI]   [6]
# 3  WORLD GROUP  QUARTERFINAL                         [Jeremy CHARDY]   [7]
# 4  WORLD GROUP  QUARTERFINAL         [Simone BOLELLI\nFabio FOGNINI]   [4]
# 5  WORLD GROUP  QUARTERFINAL  [Pierre-Hugues HERBERT\nNicolas MAHUT]   [6]
# 6  WORLD GROUP  QUARTERFINAL                         [Fabio FOGNINI]   [6]
# 7  WORLD GROUP  QUARTERFINAL                         [Lucas POUILLE]   [2]
# 8  WORLD GROUP  QUARTERFINAL                                      []    []
# 9  WORLD GROUP  QUARTERFINAL                                      []    []
#
#   Set 2 Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
# 0   [2]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1   [6]   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2   [6]   [6]         [6]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3   [2]   [2]         [8]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4   [3]   [1]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5   [6]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6   [1]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7   [6]   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8    []    []          []          []          []          NOT PLAYED  MATCH 5
# 9    []    []          []          []          []          NOT PLAYED  MATCH 5
# Loaded!
#    Team Name                 Info 1                      Info 2  \
# 0      ITALY          Fabio FOGNINI  Date of birth: 24 May 1987
# 1      ITALY          Paolo LORENZI  Date of birth: 15 Dec 1981
# 2      ITALY          Andreas SEPPI  Date of birth: 21 Feb 1984
# 3      ITALY      Matteo BERRETTINI  Date of birth: 12 Apr 1996
# 4      ITALY         Simone BOLELLI  Date of birth: 08 Oct 1985
# 5      ITALY                Captain          Corrado BARAZZUTTI
# 6     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 7     FRANCE       Adrian MANNARINO  Date of birth: 29 Jun 1988
# 8     FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
# 9     FRANCE          Jeremy CHARDY  Date of birth: 12 Feb 1987
# 10    FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 11    FRANCE                Captain                Yannick NOAH
#
#                   Info 3                Info 4
# 0   Singles ranking: 129  Doubles ranking: 127
# 1       Singles ranking:      Doubles ranking:
# 2       Singles ranking:      Doubles ranking:
# 3    Singles ranking: 90      Doubles ranking:
# 4       Singles ranking:   Doubles ranking: 55
# 5                    NaN                   NaN
# 6   Singles ranking: 333  Doubles ranking: 835
# 7    Singles ranking: 22  Doubles ranking: 286
# 8   Singles ranking: 251   Doubles ranking: 74
# 9   Singles ranking: 505  Doubles ranking: 113
# 10      Singles ranking:   Doubles ranking: 38
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['David FERRER'], 'Set 1': ['4'], 'Set 2': ['2'], 'Set 3': ['2'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Rafael NADAL'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Philipp KOHLSCHREIBER'], 'Set 1': ['2'], 'Set 2': ['2'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Feliciano LOPEZ\nMarc LOPEZ'], 'Set 1': ['3'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Tim PUETZ\nJan-Lennard STRUFF'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Rafael NADAL'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Alexander ZVEREV'], 'Set 1': ['1'], 'Set 2': ['4'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['David FERRER'], 'Set 1': ['7'], 'Set 2': ['3'], 'Set 3': ['7'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Philipp KOHLSCHREIBER'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['1'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Combined DataFrame:
#                     Date                                         Venue  \
# 0   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 1   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 2   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 3   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 4   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 5   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 6   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 7   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 8   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
# 9   06 Apr - 08 Apr 2018   Plaza de Toros de Valencia, Valencia, Spain
#
#                      Surface             Ball                      Stage  \
# 0   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 1   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 2   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 3   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 4   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 5   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 6   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 7   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 8   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
# 9   Clay - Red Clay, Outdoor   Head Davis Cup  WORLD GROUP  QUARTERFINAL
#
#                             Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
# 0                   [David FERRER]   [4]   [2]   [2]      [None]      [None]
# 1               [Alexander ZVEREV]   [6]   [6]   [6]      [None]      [None]
# 2                   [Rafael NADAL]   [6]   [6]   [6]      [None]      [None]
# 3          [Philipp KOHLSCHREIBER]   [2]   [2]   [3]      [None]      [None]
# 4    [Feliciano LOPEZ\nMarc LOPEZ]   [3]   [4]   [6]      [None]      [None]
# 5  [Tim PUETZ\nJan-Lennard STRUFF]   [6]   [6]   [3]      [None]      [None]
# 6                   [Rafael NADAL]   [6]   [6]   [6]      [None]      [None]
# 7               [Alexander ZVEREV]   [1]   [4]   [4]      [None]      [None]
# 8                   [David FERRER]   [7]   [3]   [7]         [7]      [None]
# 9          [Philipp KOHLSCHREIBER]   [6]   [6]   [6]         [1]      [None]
#
#   Tie-Break 3        match status    match
# 0      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]  PLAYED & COMPLETED  MATCH 4
# ...
# 7   14 Sep - 16 Sep 2018   Stade Pierre Mauroy, Lille, France
# 8   14 Sep - 16 Sep 2018   Stade Pierre Mauroy, Lille, France
# 9   14 Sep - 16 Sep 2018   Stade Pierre Mauroy, Lille, France
#
#                                Surface               Ball  \
# 0   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 1   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 2   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 3   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 4   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 5   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 6   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 7   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 8   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
# 9   Hard - Rebound Ace Synpave, Indoor   Tecnifibre X-One
#
#                     Stage                                Player Set 1 Set 2  \
# 0  WORLD GROUP  SEMIFINAL                        [Benoit PAIRE]   [7]   [6]
# 1  WORLD GROUP  SEMIFINAL                 [Pablo CARRENO BUSTA]   [5]   [1]
# 2  WORLD GROUP  SEMIFINAL                       [Lucas POUILLE]   [3]   [7]
# 3  WORLD GROUP  SEMIFINAL               [Roberto BAUTISTA AGUT]   [6]   [6]
# 4  WORLD GROUP  SEMIFINAL     [Julien BENNETEAU\nNicolas MAHUT]   [6]   [6]
# 5  WORLD GROUP  SEMIFINAL  [Marcel GRANOLLERS\nFeliciano LOPEZ]   [0]   [4]
# 6  WORLD GROUP  SEMIFINAL                     [Richard GASQUET]   [6]   [4]
# 7  WORLD GROUP  SEMIFINAL                [Albert RAMOS-VINOLAS]   [1]   [6]
# 8  WORLD GROUP  SEMIFINAL                       [Nicolas MAHUT]   [7]   [3]
# 9  WORLD GROUP  SEMIFINAL                   [Marcel GRANOLLERS]   [6]   [6]
#
#   Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status    match
# 0   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1   [0]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3   [4]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4   [7]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5   [6]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6  [12]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7  [14]      [None]      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8  [11]         [7]      [None]      [None]  PLAYED & COMPLETED  MATCH 5
# 9  [13]         [2]      [None]      [None]  PLAYED & COMPLETED  MATCH 5
# Loaded!
#    Team Name                 Info 1                      Info 2  \
# 0     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 1     FRANCE        Richard GASQUET  Date of birth: 18 Jun 1986
# 2     FRANCE           Benoit PAIRE  Date of birth: 08 May 1989
# 3     FRANCE       Julien BENNETEAU  Date of birth: 20 Dec 1981
# 4     FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 5     FRANCE                Captain                Yannick NOAH
# 6      SPAIN    Pablo CARRENO BUSTA  Date of birth: 12 Jul 1991
# 7      SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
# 8      SPAIN   Albert RAMOS-VINOLAS  Date of birth: 17 Jan 1988
# 9      SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
# 10     SPAIN      Marcel GRANOLLERS  Date of birth: 12 Apr 1986
# 11     SPAIN                Captain              Sergi BRUGUERA
#
#                   Info 3                Info 4
# 0   Singles ranking: 333  Doubles ranking: 835
# 1    Singles ranking: 79      Doubles ranking:
# 2   Singles ranking: 126  Doubles ranking: 526
# 3       Singles ranking:      Doubles ranking:
# 4       Singles ranking:   Doubles ranking: 38
# 5                    NaN                   NaN
# 6   Singles ranking: 603      Doubles ranking:
# 7    Singles ranking: 62      Doubles ranking:
# 8    Singles ranking: 94      Doubles ranking:
# 9   Singles ranking: 460      Doubles ranking:
# 10      Singles ranking:   Doubles ranking: 10
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Borna CORIC'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Steve JOHNSON'], 'Set 1': ['4'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marin CILIC'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['7'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Frances TIAFOE'], 'Set 1': ['1'], 'Set 2': ['3'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ivan DODIG\nMate PAVIC'], 'Set 1': ['5'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Mike BRYAN\nRyan HARRISON'], 'Set 1': ['7'], 'Set 2': ['7'], 'Set 3': ['1'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marin CILIC'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Sam QUERREY'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': ['2'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Borna CORIC'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['0'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Frances TIAFOE'], 'Set 1': ['7'], 'Set 2': ['1'], 'Set 3': ['7'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Combined DataFrame:
#                     Date                                     Venue  \
# 0   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 1   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 2   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 3   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 4   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 5   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 6   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 7   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 8   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 9   14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
#
#                      Surface                     Ball                   Stage  \
# 0   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 1   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 2   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 3   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 4   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 5   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 6   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 7   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 8   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
# 9   Clay - Red Clay, Outdoor   Dunlop Fort Clay Court  WORLD GROUP  SEMIFINAL
#
#                         Player Set 1 Set 2 Set 3 Tie-Break 1 Tie-Break 2  \
# 0                [Borna CORIC]   [6]   [7]   [6]      [None]      [None]
# 1              [Steve JOHNSON]   [4]   [6]   [3]      [None]      [None]
# 2                [Marin CILIC]   [6]   [6]   [7]      [None]      [None]
# 3             [Frances TIAFOE]   [1]   [3]   [6]      [None]      [None]
# 4     [Ivan DODIG\nMate PAVIC]   [5]   [6]   [6]      [None]      [None]
# 5  [Mike BRYAN\nRyan HARRISON]   [7]   [7]   [1]      [None]      [None]
# 6                [Marin CILIC]   [7]   [6]   [3]         [7]      [None]
# 7                [Sam QUERREY]   [6]   [7]   [6]         [2]      [None]
# 8                [Borna CORIC]   [6]   [6]   [6]         [0]      [None]
# 9             [Frances TIAFOE]   [7]   [1]   [7]         [7]      [None]
#
#   Tie-Break 3        match status    match
# 0      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]  PLAYED & COMPLETED  MATCH 4
# 8      [None]  PLAYED & COMPLETED  MATCH 5
# 9      [None]  PLAYED & COMPLETED  MATCH 5
# Loaded!
#    Team Name          Info 1                      Info 2  \
# 0    CROATIA     Marin CILIC  Date of birth: 28 Sep 1988
# 1    CROATIA     Borna CORIC  Date of birth: 14 Nov 1996
# 2    CROATIA   Franko SKUGOR  Date of birth: 20 Sep 1987
# 3    CROATIA      Mate PAVIC  Date of birth: 04 Jul 1993
# 4    CROATIA      Ivan DODIG  Date of birth: 02 Jan 1985
# 5    CROATIA         Captain               Zeljko KRAJAN
# 6        USA   Steve JOHNSON  Date of birth: 24 Dec 1989
# 7        USA  Frances TIAFOE  Date of birth: 20 Jan 1998
# 8        USA   Ryan HARRISON  Date of birth: 07 May 1992
# 9        USA     Sam QUERREY  Date of birth: 07 Oct 1987
# 10       USA      Mike BRYAN  Date of birth: 29 Apr 1978
# 11       USA         Captain                 Jim COURIER
#
#                   Info 3                Info 4
# 0   Singles ranking: 666      Doubles ranking:
# 1    Singles ranking: 37      Doubles ranking:
# 2       Singles ranking:  Doubles ranking: 169
# 3       Singles ranking:   Doubles ranking: 32
# 4       Singles ranking:    Doubles ranking: 2
# 5                    NaN                   NaN
# 6   Singles ranking: 226      Doubles ranking:
# 7    Singles ranking: 16  Doubles ranking: 196
# 8   Singles ranking: 828  Doubles ranking: 834
# 9       Singles ranking:      Doubles ranking:
# 10      Singles ranking:      Doubles ranking:
# 11                   NaN                   NaN
# Loaded!
# {'Player': ['Jeremy CHARDY'], 'Set 1': ['2'], 'Set 2': ['5'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Borna CORIC'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Jo-Wilfried TSONGA'], 'Set 1': ['3'], 'Set 2': ['5'], 'Set 3': ['4'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marin CILIC'], 'Set 1': ['6'], 'Set 2': ['7'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Pierre-Hugues HERBERT\nNicolas MAHUT'], 'Set 1': ['6'], 'Set 2': ['6'], 'Set 3': ['3'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Ivan DODIG\nMate PAVIC'], 'Set 1': ['4'], 'Set 2': ['4'], 'Set 3': ['6'], 'Tie-Break 1': [None], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Lucas POUILLE'], 'Set 1': ['6'], 'Set 2': ['3'], 'Set 3': ['3'], 'Tie-Break 1': ['3'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# {'Player': ['Marin CILIC'], 'Set 1': ['7'], 'Set 2': ['6'], 'Set 3': ['6'], 'Tie-Break 1': ['7'], 'Tie-Break 2': [None], 'Tie-Break 3': [None]}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Skipping match 5
# {'Player': [], 'Set 1': [], 'Set 2': [], 'Set 3': [], 'Tie-Break 1': [], 'Tie-Break 2': [], 'Tie-Break 3': []}
# Combined DataFrame:
#                     Date                                Venue  \
# 0   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 1   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 2   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 3   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 4   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 5   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 6   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 7   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 8   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 9   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
#
#                     Surface                     Ball             Stage  \
# 0   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 1   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 2   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 3   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 4   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 5   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 6   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 7   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 8   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 9   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
#
#                                    Player Set 1 Set 2 Set 3 Tie-Break 1  \
# 0                         [Jeremy CHARDY]   [2]   [5]   [4]      [None]
# 1                           [Borna CORIC]   [6]   [7]   [6]      [None]
# 2                    [Jo-Wilfried TSONGA]   [3]   [5]   [4]      [None]
# 3                           [Marin CILIC]   [6]   [7]   [6]      [None]
# 4  [Pierre-Hugues HERBERT\nNicolas MAHUT]   [6]   [6]   [3]      [None]
# 5                [Ivan DODIG\nMate PAVIC]   [4]   [4]   [6]      [None]
# 6                         [Lucas POUILLE]   [6]   [3]   [3]         [3]
# 7                           [Marin CILIC]   [7]   [6]   [6]         [7]
# 8                                      []    []    []    []          []
# 9                                      []    []    []    []          []
#
#   Tie-Break 2 Tie-Break 3        match status    match
# 0      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 1      [None]      [None]  PLAYED & COMPLETED  MATCH 1
# 2      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 3      [None]      [None]  PLAYED & COMPLETED  MATCH 2
# 4      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 5      [None]      [None]  PLAYED & COMPLETED  MATCH 3
# 6      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 7      [None]      [None]  PLAYED & COMPLETED  MATCH 4
# 8          []          []          NOT PLAYED  MATCH 5
# 9          []          []          NOT PLAYED  MATCH 5
# Loaded!
#    Team Name                 Info 1                      Info 2  \
# 0     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 1     FRANCE          Jeremy CHARDY  Date of birth: 12 Feb 1987
# 2     FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
# 3     FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 4     FRANCE     Jo-Wilfried TSONGA  Date of birth: 17 Apr 1985
# 5     FRANCE                Captain                Yannick NOAH
# 6    CROATIA            Marin CILIC  Date of birth: 28 Sep 1988
# 7    CROATIA            Borna CORIC  Date of birth: 14 Nov 1996
# 8    CROATIA          Franko SKUGOR  Date of birth: 20 Sep 1987
# 9    CROATIA             Mate PAVIC  Date of birth: 04 Jul 1993
# 10   CROATIA             Ivan DODIG  Date of birth: 02 Jan 1985
# 11   CROATIA                Captain               Zeljko KRAJAN
#
#                   Info 3                Info 4
# 0   Singles ranking: 333  Doubles ranking: 835
# 1   Singles ranking: 505  Doubles ranking: 113
# 2   Singles ranking: 251   Doubles ranking: 74
# 3       Singles ranking:   Doubles ranking: 38
# 4       Singles ranking:      Doubles ranking:
# 5                    NaN                   NaN
# 6   Singles ranking: 666      Doubles ranking:
# 7    Singles ranking: 37      Doubles ranking:
# 8       Singles ranking:  Doubles ranking: 169
# 9       Singles ranking:   Doubles ranking: 32
# 10      Singles ranking:    Doubles ranking: 2
# 11                   NaN                   NaN

# %% [markdown]
# ## outputs

# %%
matches_df.shape
# Out:
# (110, 15)

# %%
matches_df.iloc[90:110]
# Out:
#                       Date                                     Venue  \
# 90    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 91    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 92    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 93    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 94    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 95    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 96    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 97    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 98    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 99    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 100   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 101   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 102   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 103   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 104   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 105   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 106   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 107   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 108   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 109   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
#
#                        Surface                     Ball  \
# 90    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 91    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 92    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 93    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 94    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 95    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 96    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 97    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 98    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 99    Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 100    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 101    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 102    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 103    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 104    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 105    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 106    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 107    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 108    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 109    Clay - Red Clay, Indoor   Dunlop Fort Clay Court
#
#                       Stage                                  Player Set 1  \
# 90   WORLD GROUP  SEMIFINAL                           [Borna CORIC]   [6]
# 91   WORLD GROUP  SEMIFINAL                         [Steve JOHNSON]   [4]
# 92   WORLD GROUP  SEMIFINAL                           [Marin CILIC]   [6]
# 93   WORLD GROUP  SEMIFINAL                        [Frances TIAFOE]   [1]
# 94   WORLD GROUP  SEMIFINAL                [Ivan DODIG\nMate PAVIC]   [5]
# 95   WORLD GROUP  SEMIFINAL             [Mike BRYAN\nRyan HARRISON]   [7]
# 96   WORLD GROUP  SEMIFINAL                           [Marin CILIC]   [7]
# 97   WORLD GROUP  SEMIFINAL                           [Sam QUERREY]   [6]
# 98   WORLD GROUP  SEMIFINAL                           [Borna CORIC]   [6]
# 99   WORLD GROUP  SEMIFINAL                        [Frances TIAFOE]   [7]
# 100        DAVIS CUP  FINAL                         [Jeremy CHARDY]   [2]
# 101        DAVIS CUP  FINAL                           [Borna CORIC]   [6]
# 102        DAVIS CUP  FINAL                    [Jo-Wilfried TSONGA]   [3]
# 103        DAVIS CUP  FINAL                           [Marin CILIC]   [6]
# 104        DAVIS CUP  FINAL  [Pierre-Hugues HERBERT\nNicolas MAHUT]   [6]
# 105        DAVIS CUP  FINAL                [Ivan DODIG\nMate PAVIC]   [4]
# 106        DAVIS CUP  FINAL                         [Lucas POUILLE]   [6]
# 107        DAVIS CUP  FINAL                           [Marin CILIC]   [7]
# 108        DAVIS CUP  FINAL                                      []    []
# 109        DAVIS CUP  FINAL                                      []    []
#
#     Set 2 Set 3 Tie-Break 1 Tie-Break 2 Tie-Break 3        match status  \
# 90    [7]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED
# 91    [6]   [3]      [None]      [None]      [None]  PLAYED & COMPLETED
# 92    [6]   [7]      [None]      [None]      [None]  PLAYED & COMPLETED
# 93    [3]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED
# 94    [6]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED
# 95    [7]   [1]      [None]      [None]      [None]  PLAYED & COMPLETED
# 96    [6]   [3]         [7]      [None]      [None]  PLAYED & COMPLETED
# 97    [7]   [6]         [2]      [None]      [None]  PLAYED & COMPLETED
# 98    [6]   [6]         [0]      [None]      [None]  PLAYED & COMPLETED
# 99    [1]   [7]         [7]      [None]      [None]  PLAYED & COMPLETED
# 100   [5]   [4]      [None]      [None]      [None]  PLAYED & COMPLETED
# 101   [7]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED
# 102   [5]   [4]      [None]      [None]      [None]  PLAYED & COMPLETED
# 103   [7]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED
# 104   [6]   [3]      [None]      [None]      [None]  PLAYED & COMPLETED
# 105   [4]   [6]      [None]      [None]      [None]  PLAYED & COMPLETED
# 106   [3]   [3]         [3]      [None]      [None]  PLAYED & COMPLETED
# 107   [6]   [6]         [7]      [None]      [None]  PLAYED & COMPLETED
# 108    []    []          []          []          []          NOT PLAYED
# 109    []    []          []          []          []          NOT PLAYED
#
#        match Court Pace Rating
# 90   MATCH 1               NaN
# 91   MATCH 1               NaN
# 92   MATCH 2               NaN
# 93   MATCH 2               NaN
# 94   MATCH 3               NaN
# 95   MATCH 3               NaN
# 96   MATCH 4               NaN
# 97   MATCH 4               NaN
# 98   MATCH 5               NaN
# 99   MATCH 5               NaN
# 100  MATCH 1               NaN
# 101  MATCH 1               NaN
# 102  MATCH 2               NaN
# 103  MATCH 2               NaN
# 104  MATCH 3               NaN
# 105  MATCH 3               NaN
# 106  MATCH 4               NaN
# 107  MATCH 4               NaN
# 108  MATCH 5               NaN
# 109  MATCH 5               NaN

# %%
players_df.shape
# Out:
# (175, 5)

# %%
players_df.iloc[90:110]
# Out:
#     Team Name                 Info 1                      Info 2  \
# 90    HUNGARY           Mate VALKUSZ  Date of birth: 13 Aug 1998
# 91    HUNGARY           Gabor BORSOS  Date of birth: 30 Jun 1991
# 92    HUNGARY                Captain                 Gabor KOVES
# 93      ITALY          Fabio FOGNINI  Date of birth: 24 May 1987
# 94      ITALY          Paolo LORENZI  Date of birth: 15 Dec 1981
# 95      ITALY          Andreas SEPPI  Date of birth: 21 Feb 1984
# 96      ITALY      Matteo BERRETTINI  Date of birth: 12 Apr 1996
# 97      ITALY         Simone BOLELLI  Date of birth: 08 Oct 1985
# 98      ITALY                Captain          Corrado BARAZZUTTI
# 99     FRANCE          Lucas POUILLE  Date of birth: 23 Feb 1994
# 100    FRANCE       Adrian MANNARINO  Date of birth: 29 Jun 1988
# 101    FRANCE  Pierre-Hugues HERBERT  Date of birth: 18 Mar 1991
# 102    FRANCE          Jeremy CHARDY  Date of birth: 12 Feb 1987
# 103    FRANCE          Nicolas MAHUT  Date of birth: 21 Jan 1982
# 104    FRANCE                Captain                Yannick NOAH
# 105     SPAIN           Rafael NADAL  Date of birth: 03 Jun 1986
# 106     SPAIN  Roberto BAUTISTA AGUT  Date of birth: 14 Apr 1988
# 107     SPAIN        Feliciano LOPEZ  Date of birth: 20 Sep 1981
# 108     SPAIN           David FERRER  Date of birth: 02 Apr 1982
# 109     SPAIN                Captain              Sergi BRUGUERA
#
#                    Info 3                  Info 4
# 90   Singles ranking: 216        Doubles ranking:
# 91       Singles ranking:  Doubles ranking: 1628=
# 92                    NaN                     NaN
# 93   Singles ranking: 129    Doubles ranking: 127
# 94       Singles ranking:        Doubles ranking:
# 95       Singles ranking:        Doubles ranking:
# 96    Singles ranking: 90        Doubles ranking:
# 97       Singles ranking:     Doubles ranking: 55
# 98                    NaN                     NaN
# 99   Singles ranking: 333    Doubles ranking: 835
# 100   Singles ranking: 22    Doubles ranking: 286
# 101  Singles ranking: 251     Doubles ranking: 74
# 102  Singles ranking: 505    Doubles ranking: 113
# 103      Singles ranking:     Doubles ranking: 38
# 104                   NaN                     NaN
# 105  Singles ranking: 664        Doubles ranking:
# 106   Singles ranking: 62        Doubles ranking:
# 107  Singles ranking: 460        Doubles ranking:
# 108      Singles ranking:        Doubles ranking:
# 109                   NaN                     NaN

# %%
duplicate_rows = players_df.duplicated()
duplicate_rows_df = players_df[duplicate_rows]
duplicate_rows_df
# Out:
#     Team Name          Info 1                      Info 2  \
# 93      ITALY   Fabio FOGNINI  Date of birth: 24 May 1987
# 94      ITALY   Paolo LORENZI  Date of birth: 15 Dec 1981
# 95      ITALY   Andreas SEPPI  Date of birth: 21 Feb 1984
# 97      ITALY  Simone BOLELLI  Date of birth: 08 Oct 1985
# 98      ITALY         Captain          Corrado BARAZZUTTI
# ..        ...             ...                         ...
# 170   CROATIA     Borna CORIC  Date of birth: 14 Nov 1996
# 171   CROATIA   Franko SKUGOR  Date of birth: 20 Sep 1987
# 172   CROATIA      Mate PAVIC  Date of birth: 04 Jul 1993
# 173   CROATIA      Ivan DODIG  Date of birth: 02 Jan 1985
# 174   CROATIA         Captain               Zeljko KRAJAN
#
#                    Info 3                Info 4
# 93   Singles ranking: 129  Doubles ranking: 127
# 94       Singles ranking:      Doubles ranking:
# 95       Singles ranking:      Doubles ranking:
# 97       Singles ranking:   Doubles ranking: 55
# 98                    NaN                   NaN
# ..                    ...                   ...
# 170   Singles ranking: 37      Doubles ranking:
# 171      Singles ranking:  Doubles ranking: 169
# 172      Singles ranking:   Doubles ranking: 32
# 173      Singles ranking:    Doubles ranking: 2
# 174                   NaN                   NaN
#
# [65 rows x 5 columns]

# %% [markdown]
# # Clean players and matches dataframes

# %%
def clean_players_df(players_df):
    # Remove rows where Info 1 is equal to "captain"
    players_df = players_df[players_df["Info 1"] != "Captain"]
    
    # Rename the columns
    players_df = players_df.rename(columns={"Info 1": "Player", "Info 2": "DOB", "Info 3": "Single Ranking", "Info 4": "Doubles Ranking"})
    
    # Remove text before ":" in the specified columns
    players_df["DOB"] = players_df["DOB"].str.split(":", expand=True)[1].str.strip()
    players_df["Single Ranking"] = players_df["Single Ranking"].str.split(":", expand=True)[1].str.strip()
    players_df["Doubles Ranking"] = players_df["Doubles Ranking"].str.split(":", expand=True)[1].str.strip()
    
    # Keep the first letter in each word in uppercase for the "Player" column in players_df
    players_df['Player'] = players_df['Player'].str.title()
    
    return players_df

# %%
# Usage example:
# Call the clean_df_players function with your players_df DataFrame
cleaned_players_df = clean_players_df(players_df)

# %%
cleaned_players_df.iloc[130:145]
# Out:
#     Team Name                 Player          DOB Single Ranking  \
# 157       USA          Steve Johnson  24 Dec 1989            226
# 158       USA         Frances Tiafoe  20 Jan 1998             16
# 159       USA          Ryan Harrison  07 May 1992            828
# 160       USA            Sam Querrey  07 Oct 1987
# 161       USA             Mike Bryan  29 Apr 1978
# 163    FRANCE          Lucas Pouille  23 Feb 1994            333
# 164    FRANCE          Jeremy Chardy  12 Feb 1987            505
# 165    FRANCE  Pierre-Hugues Herbert  18 Mar 1991            251
# 166    FRANCE          Nicolas Mahut  21 Jan 1982
# 167    FRANCE     Jo-Wilfried Tsonga  17 Apr 1985
# 169   CROATIA            Marin Cilic  28 Sep 1988            666
# 170   CROATIA            Borna Coric  14 Nov 1996             37
# 171   CROATIA          Franko Skugor  20 Sep 1987
# 172   CROATIA             Mate Pavic  04 Jul 1993
# 173   CROATIA             Ivan Dodig  02 Jan 1985
#
#     Doubles Ranking
# 157
# 158             196
# 159             834
# 160
# 161
# 163             835
# 164             113
# 165              74
# 166              38
# 167
# 169
# 170
# 171             169
# 172              32
# 173               2

# %%
def clean_matches_df(matches_df):
    # Convert "Player" and set columns to string
    columns_to_convert = ["Player", "Set 1", "Set 2", "Set 3", "Tie-Break 1", "Tie-Break 2", "Tie-Break 3"]
    matches_df[columns_to_convert] = matches_df[columns_to_convert].astype(str)

    # Define a function to apply regular expression replacements
    def apply_regex_replacements(df, columns):
        for col in columns:
            df[col] = df[col].str.replace(r'[\[\]\']+| and ', '', regex=True)

    # Apply the function to the specified columns
    columns_to_clean = ["Player", "Set 1", "Set 2", "Set 3", "Tie-Break 1", "Tie-Break 2", "Tie-Break 3"]
    apply_regex_replacements(matches_df, columns_to_clean)

    # Apply the str.extract method with the specified regular expression
    split_players = matches_df['Player'].str.extract(r'^(.*?)\\n(.*)$')
    
    # Create 'Player 1' and 'Player 2' columns
    matches_df['Player 1'] = split_players[0].fillna(matches_df['Player'])
    matches_df['Player 2'] = split_players[1].fillna('')
    
    # Drop the original 'Player' column
    matches_df.drop('Player', axis=1, inplace=True)
    
    # Keep the first letter in each word in uppercase for the "Player 1" and "Player 2" columns
    matches_df["Player 1"] = matches_df["Player 1"].str.title()
    matches_df["Player 2"] = matches_df["Player 2"].str.title()
    
    # Define a function to convert specific columns from string to numeric
    def convert_columns_to_numeric(df, columns):
        for col in columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    # Specify the columns to convert
    columns_to_convert = ["Set 1", "Set 2", "Set 3", "Tie-Break 1", "Tie-Break 2", "Tie-Break 3"]

    # Apply the function to convert the specified columns
    convert_columns_to_numeric(matches_df, columns_to_convert)
    
    return matches_df

# %%
# Usage example:
# Call the clean_df_combined function with your combined_df DataFrame
cleaned_matches_df = clean_matches_df(matches_df)

# %%
cleaned_matches_df.iloc[80:110]
# Out:
#                       Date                                     Venue  \
# 80    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 81    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 82    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 83    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 84    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 85    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 86    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 87    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 88    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 89    14 Sep - 16 Sep 2018        Stade Pierre Mauroy, Lille, France
# 90    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 91    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 92    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 93    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 94    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 95    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 96    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 97    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 98    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 99    14 Sep - 16 Sep 2018   Sportski centar Visnjik, Zadar, Croatia
# 100   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 101   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 102   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 103   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 104   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 105   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 106   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 107   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 108   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
# 109   23 Nov - 25 Nov 2018        Stade Pierre Mauroy, Lille, France
#
#                                  Surface                     Ball  \
# 80    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 81    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 82    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 83    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 84    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 85    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 86    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 87    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 88    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 89    Hard - Rebound Ace Synpave, Indoor         Tecnifibre X-One
# 90              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 91              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 92              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 93              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 94              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 95              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 96              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 97              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 98              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 99              Clay - Red Clay, Outdoor   Dunlop Fort Clay Court
# 100              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 101              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 102              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 103              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 104              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 105              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 106              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 107              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 108              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
# 109              Clay - Red Clay, Indoor   Dunlop Fort Clay Court
#
#                       Stage  Set 1  Set 2  Set 3  Tie-Break 1  Tie-Break 2  \
# 80   WORLD GROUP  SEMIFINAL    7.0    6.0    6.0          NaN          NaN
# 81   WORLD GROUP  SEMIFINAL    5.0    1.0    0.0          NaN          NaN
# 82   WORLD GROUP  SEMIFINAL    3.0    7.0    6.0          NaN          NaN
# 83   WORLD GROUP  SEMIFINAL    6.0    6.0    4.0          NaN          NaN
# 84   WORLD GROUP  SEMIFINAL    6.0    6.0    7.0          NaN          NaN
# 85   WORLD GROUP  SEMIFINAL    0.0    4.0    6.0          NaN          NaN
# 86   WORLD GROUP  SEMIFINAL    6.0    4.0   12.0          NaN          NaN
# 87   WORLD GROUP  SEMIFINAL    1.0    6.0   14.0          NaN          NaN
# 88   WORLD GROUP  SEMIFINAL    7.0    3.0   11.0          7.0          NaN
# 89   WORLD GROUP  SEMIFINAL    6.0    6.0   13.0          2.0          NaN
# 90   WORLD GROUP  SEMIFINAL    6.0    7.0    6.0          NaN          NaN
# 91   WORLD GROUP  SEMIFINAL    4.0    6.0    3.0          NaN          NaN
# 92   WORLD GROUP  SEMIFINAL    6.0    6.0    7.0          NaN          NaN
# 93   WORLD GROUP  SEMIFINAL    1.0    3.0    6.0          NaN          NaN
# 94   WORLD GROUP  SEMIFINAL    5.0    6.0    6.0          NaN          NaN
# 95   WORLD GROUP  SEMIFINAL    7.0    7.0    1.0          NaN          NaN
# 96   WORLD GROUP  SEMIFINAL    7.0    6.0    3.0          7.0          NaN
# 97   WORLD GROUP  SEMIFINAL    6.0    7.0    6.0          2.0          NaN
# 98   WORLD GROUP  SEMIFINAL    6.0    6.0    6.0          0.0          NaN
# 99   WORLD GROUP  SEMIFINAL    7.0    1.0    7.0          7.0          NaN
# 100        DAVIS CUP  FINAL    2.0    5.0    4.0          NaN          NaN
# 101        DAVIS CUP  FINAL    6.0    7.0    6.0          NaN          NaN
# 102        DAVIS CUP  FINAL    3.0    5.0    4.0          NaN          NaN
# 103        DAVIS CUP  FINAL    6.0    7.0    6.0          NaN          NaN
# 104        DAVIS CUP  FINAL    6.0    6.0    3.0          NaN          NaN
# 105        DAVIS CUP  FINAL    4.0    4.0    6.0          NaN          NaN
# 106        DAVIS CUP  FINAL    6.0    3.0    3.0          3.0          NaN
# 107        DAVIS CUP  FINAL    7.0    6.0    6.0          7.0          NaN
# 108        DAVIS CUP  FINAL    NaN    NaN    NaN          NaN          NaN
# 109        DAVIS CUP  FINAL    NaN    NaN    NaN          NaN          NaN
#
#      Tie-Break 3        match status    match Court Pace Rating  \
# 80           NaN  PLAYED & COMPLETED  MATCH 1               NaN
# 81           NaN  PLAYED & COMPLETED  MATCH 1               NaN
# 82           NaN  PLAYED & COMPLETED  MATCH 2               NaN
# 83           NaN  PLAYED & COMPLETED  MATCH 2               NaN
# 84           NaN  PLAYED & COMPLETED  MATCH 3               NaN
# 85           NaN  PLAYED & COMPLETED  MATCH 3               NaN
# 86           NaN  PLAYED & COMPLETED  MATCH 4               NaN
# 87           NaN  PLAYED & COMPLETED  MATCH 4               NaN
# 88           NaN  PLAYED & COMPLETED  MATCH 5               NaN
# 89           NaN  PLAYED & COMPLETED  MATCH 5               NaN
# 90           NaN  PLAYED & COMPLETED  MATCH 1               NaN
# 91           NaN  PLAYED & COMPLETED  MATCH 1               NaN
# 92           NaN  PLAYED & COMPLETED  MATCH 2               NaN
# 93           NaN  PLAYED & COMPLETED  MATCH 2               NaN
# 94           NaN  PLAYED & COMPLETED  MATCH 3               NaN
# 95           NaN  PLAYED & COMPLETED  MATCH 3               NaN
# 96           NaN  PLAYED & COMPLETED  MATCH 4               NaN
# 97           NaN  PLAYED & COMPLETED  MATCH 4               NaN
# 98           NaN  PLAYED & COMPLETED  MATCH 5               NaN
# 99           NaN  PLAYED & COMPLETED  MATCH 5               NaN
# 100          NaN  PLAYED & COMPLETED  MATCH 1               NaN
# 101          NaN  PLAYED & COMPLETED  MATCH 1               NaN
# 102          NaN  PLAYED & COMPLETED  MATCH 2               NaN
# 103          NaN  PLAYED & COMPLETED  MATCH 2               NaN
# 104          NaN  PLAYED & COMPLETED  MATCH 3               NaN
# 105          NaN  PLAYED & COMPLETED  MATCH 3               NaN
# 106          NaN  PLAYED & COMPLETED  MATCH 4               NaN
# 107          NaN  PLAYED & COMPLETED  MATCH 4               NaN
# 108          NaN          NOT PLAYED  MATCH 5               NaN
# 109          NaN          NOT PLAYED  MATCH 5               NaN
#
#                   Player 1         Player 2
# 80            Benoit Paire
# 81     Pablo Carreno Busta
# 82           Lucas Pouille
# 83   Roberto Bautista Agut
# 84        Julien Benneteau    Nicolas Mahut
# 85       Marcel Granollers  Feliciano Lopez
# 86         Richard Gasquet
# 87    Albert Ramos-Vinolas
# 88           Nicolas Mahut
# 89       Marcel Granollers
# 90             Borna Coric
# 91           Steve Johnson
# 92             Marin Cilic
# 93          Frances Tiafoe
# 94              Ivan Dodig       Mate Pavic
# 95              Mike Bryan    Ryan Harrison
# 96             Marin Cilic
# 97             Sam Querrey
# 98             Borna Coric
# 99          Frances Tiafoe
# 100          Jeremy Chardy
# 101            Borna Coric
# 102     Jo-Wilfried Tsonga
# 103            Marin Cilic
# 104  Pierre-Hugues Herbert    Nicolas Mahut
# 105             Ivan Dodig       Mate Pavic
# 106          Lucas Pouille
# 107            Marin Cilic
# 108
# 109

# %% [markdown]
# # Merge players and matches dataframes

# %%
def merge_data_frames(df1, df2):
    # First merge based on "Player" matching "Player 1"
    merged_df = df1.merge(df2, left_on='Player 1', right_on='Player', how='left')

    # Second merge based on "Player" matching "Player 2"
    merged_df = merged_df.merge(df2, left_on='Player 2', right_on='Player', how='left')

    # Rename columns if needed
    merged_df.rename(columns={'Name_x': 'Player_1_Name', 'Country_x': 'Player_1_Country',
                             'Name_y': 'Player_2_Name', 'Country_y': 'Player_2_Country'}, inplace=True)

    # Drop the duplicated columns
    merged_df.drop(['Player_x', 'Player_y'], axis=1, inplace=True)

    return merged_df

# %%
merged_df = merge_data_frames(cleaned_matches_df, cleaned_players_df)

# %%
merged_df.iloc[260:290]
# Out:
#                       Date                                Venue  \
# 260   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 261   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 262   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 263   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 264   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 265   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 266   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 267   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 268   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 269   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 270   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 271   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 272   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 273   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 274   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 275   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 276   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 277   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 278   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 279   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 280   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 281   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 282   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 283   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 284   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 285   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 286   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 287   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 288   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
# 289   23 Nov - 25 Nov 2018   Stade Pierre Mauroy, Lille, France
#
#                       Surface                     Ball             Stage  \
# 260   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 261   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 262   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 263   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 264   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 265   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 266   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 267   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 268   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 269   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 270   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 271   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 272   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 273   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 274   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 275   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 276   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 277   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 278   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 279   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 280   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 281   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 282   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 283   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 284   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 285   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 286   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 287   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 288   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
# 289   Clay - Red Clay, Indoor   Dunlop Fort Clay Court  DAVIS CUP  FINAL
#
#      Set 1  Set 2  Set 3  Tie-Break 1  Tie-Break 2  ...  \
# 260    6.0    6.0    3.0          NaN          NaN  ...
# 261    6.0    6.0    3.0          NaN          NaN  ...
# 262    6.0    6.0    3.0          NaN          NaN  ...
# 263    6.0    6.0    3.0          NaN          NaN  ...
# 264    6.0    6.0    3.0          NaN          NaN  ...
# 265    6.0    6.0    3.0          NaN          NaN  ...
# 266    6.0    6.0    3.0          NaN          NaN  ...
# 267    6.0    6.0    3.0          NaN          NaN  ...
# 268    6.0    6.0    3.0          NaN          NaN  ...
# 269    6.0    6.0    3.0          NaN          NaN  ...
# 270    6.0    6.0    3.0          NaN          NaN  ...
# 271    6.0    6.0    3.0          NaN          NaN  ...
# 272    4.0    4.0    6.0          NaN          NaN  ...
# 273    4.0    4.0    6.0          NaN          NaN  ...
# 274    4.0    4.0    6.0          NaN          NaN  ...
# 275    4.0    4.0    6.0          NaN          NaN  ...
# 276    4.0    4.0    6.0          NaN          NaN  ...
# 277    4.0    4.0    6.0          NaN          NaN  ...
# 278    4.0    4.0    6.0          NaN          NaN  ...
# 279    4.0    4.0    6.0          NaN          NaN  ...
# 280    6.0    3.0    3.0          3.0          NaN  ...
# 281    6.0    3.0    3.0          3.0          NaN  ...
# 282    6.0    3.0    3.0          3.0          NaN  ...
# 283    6.0    3.0    3.0          3.0          NaN  ...
# 284    7.0    6.0    6.0          7.0          NaN  ...
# 285    7.0    6.0    6.0          7.0          NaN  ...
# 286    7.0    6.0    6.0          7.0          NaN  ...
# 287    7.0    6.0    6.0          7.0          NaN  ...
# 288    NaN    NaN    NaN          NaN          NaN  ...
# 289    NaN    NaN    NaN          NaN          NaN  ...
#
#                   Player 1       Player 2 Team Name_x        DOB_x  \
# 260  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 261  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 262  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 263  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 264  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 265  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 266  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 267  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 268  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 269  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 270  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 271  Pierre-Hugues Herbert  Nicolas Mahut      FRANCE  18 Mar 1991
# 272             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 273             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 274             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 275             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 276             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 277             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 278             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 279             Ivan Dodig     Mate Pavic     CROATIA  02 Jan 1985
# 280          Lucas Pouille                     FRANCE  23 Feb 1994
# 281          Lucas Pouille                     FRANCE  23 Feb 1994
# 282          Lucas Pouille                     FRANCE  23 Feb 1994
# 283          Lucas Pouille                     FRANCE  23 Feb 1994
# 284            Marin Cilic                    CROATIA  28 Sep 1988
# 285            Marin Cilic                    CROATIA  28 Sep 1988
# 286            Marin Cilic                    CROATIA  28 Sep 1988
# 287            Marin Cilic                    CROATIA  28 Sep 1988
# 288                                               NaN          NaN
# 289                                               NaN          NaN
#
#     Single Ranking_x Doubles Ranking_x Team Name_y        DOB_y  \
# 260              251                74      FRANCE  21 Jan 1982
# 261              251                74      FRANCE  21 Jan 1982
# 262              251                74      FRANCE  21 Jan 1982
# 263              251                74      FRANCE  21 Jan 1982
# 264              251                74      FRANCE  21 Jan 1982
# 265              251                74      FRANCE  21 Jan 1982
# 266              251                74      FRANCE  21 Jan 1982
# 267              251                74      FRANCE  21 Jan 1982
# 268              251                74      FRANCE  21 Jan 1982
# 269              251                74      FRANCE  21 Jan 1982
# 270              251                74      FRANCE  21 Jan 1982
# 271              251                74      FRANCE  21 Jan 1982
# 272                                  2     CROATIA  04 Jul 1993
# 273                                  2     CROATIA  04 Jul 1993
# 274                                  2     CROATIA  04 Jul 1993
# 275                                  2     CROATIA  04 Jul 1993
# 276                                  2     CROATIA  04 Jul 1993
# 277                                  2     CROATIA  04 Jul 1993
# 278                                  2     CROATIA  04 Jul 1993
# 279                                  2     CROATIA  04 Jul 1993
# 280              333               835         NaN          NaN
# 281              333               835         NaN          NaN
# 282              333               835         NaN          NaN
# 283              333               835         NaN          NaN
# 284              666                           NaN          NaN
# 285              666                           NaN          NaN
# 286              666                           NaN          NaN
# 287              666                           NaN          NaN
# 288              NaN               NaN         NaN          NaN
# 289              NaN               NaN         NaN          NaN
#
#     Single Ranking_y Doubles Ranking_y
# 260                                 38
# 261                                 38
# 262                                 38
# 263                                 38
# 264                                 38
# 265                                 38
# 266                                 38
# 267                                 38
# 268                                 38
# 269                                 38
# 270                                 38
# 271                                 38
# 272                                 32
# 273                                 32
# 274                                 32
# 275                                 32
# 276                                 32
# 277                                 32
# 278                                 32
# 279                                 32
# 280              NaN               NaN
# 281              NaN               NaN
# 282              NaN               NaN
# 283              NaN               NaN
# 284              NaN               NaN
# 285              NaN               NaN
# 286              NaN               NaN
# 287              NaN               NaN
# 288              NaN               NaN
# 289              NaN               NaN
#
# [30 rows x 24 columns]

# %% [markdown]
# # Export dataframe

# %%
# Specify the Excel file path
excel_file_path = 'merged_data.xlsx'

# Export merged_df to Excel
merged_df.to_excel(excel_file_path, index=False)

print(f"Data has been exported to {excel_file_path}")

# %% [markdown]
# # Retrieve all years links

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchWindowException
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait



# Path to the ChromeDriver
chrome_driver_path = "C:/Users/ALESSANDRO/Downloads/chromedriver.exe"

# Initialize the WebDriver
driver = webdriver.Chrome(executable_path=chrome_driver_path)

try:
    # Access the page
    driver.get("https://www.daviscup.com/en/draws-results/historic-format/world-group.aspx")

    # Wait for the selected element to be visible
    wait = WebDriverWait(driver, 10)
    selected_element = wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, "div.selected span.number")))
    
    # Extract text from the selected element
    span_text = selected_element.text
    print(f"Selected element text: {span_text}")

except TimeoutException:
    print("Timeout: Element not found or not visible within the specified time.")
