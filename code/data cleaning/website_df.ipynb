# %% [markdown]
# # Libraries

# %%
import pandas as pd
from getpass import getuser

# %% [markdown]
# # Input Directories

# %%
# Get the current user's name
user = getuser()
directory = f"C:/Users/{user}/Documents/GitHub/davis-cup/data/davis matches/combined_davis.xlsx"
df = pd.read_excel(directory)
df
# Out:
#                        date                                          venue  \
# 0      01 Feb - 03 Feb 2013   Thunderbird Sports Centre, Vancouver, Canada
# 1      01 Feb - 03 Feb 2013   Thunderbird Sports Centre, Vancouver, Canada
# 2      01 Feb - 03 Feb 2013   Thunderbird Sports Centre, Vancouver, Canada
# 3      01 Feb - 03 Feb 2013   Thunderbird Sports Centre, Vancouver, Canada
# 4      01 Feb - 03 Feb 2013   Thunderbird Sports Centre, Vancouver, Canada
# ...                     ...                                            ...
# 2269   25 Nov - 25 Nov 2023                                         Malaga
# 2270   26 Nov - 26 Nov 2023                                         Malaga
# 2271   26 Nov - 26 Nov 2023                                         Malaga
# 2272   26 Nov - 26 Nov 2023                                         Malaga
# 2273   26 Nov - 26 Nov 2023                                         Malaga
#
#                       surface                        ball  \
# 0      Hard - Premier, Indoor   Wilson US Open Extra Duty
# 1      Hard - Premier, Indoor   Wilson US Open Extra Duty
# 2      Hard - Premier, Indoor   Wilson US Open Extra Duty
# 3      Hard - Premier, Indoor   Wilson US Open Extra Duty
# 4      Hard - Premier, Indoor   Wilson US Open Extra Duty
# ...                       ...                         ...
# 2269                        ,                         NaN
# 2270                        ,                         NaN
# 2271                        ,                         NaN
# 2272                        ,                         NaN
# 2273                        ,                         NaN
#
#                        stage  set1  set2  set3  set4  set5  ...  \
# 0     WORLD GROUP  1ST ROUND   6.0   6.0   6.0   6.0   NaN  ...
# 1     WORLD GROUP  1ST ROUND   7.0   4.0   4.0   4.0   NaN  ...
# 2     WORLD GROUP  1ST ROUND   6.0   6.0   6.0   NaN   NaN  ...
# 3     WORLD GROUP  1ST ROUND   1.0   2.0   2.0   NaN   NaN  ...
# 4     WORLD GROUP  1ST ROUND   6.0   4.0   7.0   3.0   2.0  ...
# ...                      ...   ...   ...   ...   ...   ...  ...
# 2269      FINALS  SEMI-FINAL   3.0   4.0   NaN   NaN   NaN  ...
# 2270           FINALS  FINAL   5.0   6.0   4.0   NaN   NaN  ...
# 2271           FINALS  FINAL   7.0   2.0   6.0   NaN   NaN  ...
# 2272           FINALS  FINAL   3.0   0.0   NaN   NaN   NaN  ...
# 2273           FINALS  FINAL   6.0   6.0   NaN   NaN   NaN  ...
#
#                 player2  team_name  dob_player1  single_ranking_player1  \
# 0                   NaN     CANADA  27 Dec 1990                     231
# 1                   NaN      SPAIN  17 Jan 1988                     122
# 2                   NaN     CANADA  26 Sep 1984                     NaN
# 3                   NaN      SPAIN  12 Apr 1986                     NaN
# 4        Vasek Pospisil     CANADA  04 Sep 1972                     NaN
# ...                 ...        ...          ...                     ...
# 2269  Miomir Kecmanovic     SERBIA  22 May 1987                       2
# 2270                NaN  AUSTRALIA  05 Aug 1999                      28
# 2271                NaN      ITALY  22 Feb 2001                      30
# 2272                NaN  AUSTRALIA  17 Feb 1999                      10
# 2273                NaN      ITALY  16 Aug 2001                       1
#
#       doubles_ranking_player1  dob_player2 single_ranking_player2  \
# 0                         NaN          NaN                    NaN
# 1                         NaN          NaN                    NaN
# 2                         NaN          NaN                    NaN
# 3                          1=          NaN                    NaN
# 4                         NaN  23 Jun 1990                    609
# ...                       ...          ...                    ...
# 2269                      NaN  31 Aug 1999                     53
# 2270                      868          NaN                    NaN
# 2271                     545=          NaN                    NaN
# 2272                      340          NaN                    NaN
# 2273                      249          NaN                    NaN
#
#      doubles_ranking_player2  year court pace rating
# 0                        NaN  2013               NaN
# 1                        NaN  2013               NaN
# 2                        NaN  2013               NaN
# 3                        NaN  2013               NaN
# 4                      1387=  2013               NaN
# ...                      ...   ...               ...
# 2269                     412  2023               NaN
# 2270                     NaN  2023               NaN
# 2271                     NaN  2023               NaN
# 2272                     NaN  2023               NaN
# 2273                     NaN  2023               NaN
#
# [2274 rows x 28 columns]

# %%
# rename team variable
df.rename(columns={'team_name': 'team'}, inplace=True)

# %%
# Group by 'team' and 'year', then count the number of unique 'player1'
unique_players_per_team_year = df.groupby(['team', 'year'])['player1'].nunique()

# Convert the Series to a DataFrame
result_table = unique_players_per_team_year.reset_index(name='unique_player_count')

# Pivot the DataFrame to create the desired table
pivot_table = result_table.pivot(index='team', columns='year', values='unique_player_count')

# Reindex the columns to include all years from 2014 to 2023
all_years = range(2014, 2024)
pivot_table = pivot_table.reindex(columns=all_years)

# Display the resulting table
pivot_table
# Out:
# year                             2014  2015  2016  2017  2018  2019  2020  \
# team
# ARGENTINA                         3.0   4.0   7.0   2.0   NaN   3.0   NaN
# AUSTRALIA                         4.0   NaN   3.0   5.0   3.0   NaN   NaN
# AUSTRIA                           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# BELGIUM                           2.0   3.0   3.0   5.0   5.0   NaN   NaN
# BRAZIL                            NaN   3.0   NaN   NaN   NaN   NaN   NaN
# CANADA                            NaN   3.0   3.0   3.0   3.0   3.0   NaN
# CROATIA                           NaN   4.0   5.0   4.0   4.0   NaN   NaN
# CZECHIA                           4.0   NaN   2.0   2.0   NaN   NaN   NaN
# FINLAND                           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FRANCE                            4.0   4.0   6.0   8.0   9.0   NaN   NaN
# GERMANY                           7.0   3.0   NaN   3.0   4.0   NaN   NaN
# GREAT BRITAIN                     3.0   3.0   5.0   3.0   3.0   3.0   NaN
# HUNGARY                           NaN   NaN   NaN   NaN   3.0   NaN   NaN
# ISRAEL                            NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ITALY                             3.0   NaN   5.0   5.0   3.0   NaN   NaN
# JAPAN                             3.0   3.0   3.0   4.0   3.0   NaN   NaN
# KAZAKHSTAN                        3.0   NaN   3.0   NaN   4.0   NaN   NaN
# NETHERLANDS                       3.0   NaN   NaN   NaN   2.0   NaN   NaN
# POLAND                            NaN   NaN   3.0   NaN   NaN   NaN   NaN
# RUSSIA                            NaN   NaN   NaN   3.0   NaN   2.0   NaN
# RUSSIAN TENNIS FEDERATION (RTF)   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# SERBIA                            3.0   3.0   5.0   6.0   4.0   2.0   NaN
# SPAIN                             3.0   NaN   NaN   3.0   7.0   5.0   NaN
# SWEDEN                            NaN   NaN   NaN   NaN   NaN   NaN   NaN
# SWITZERLAND                       4.0   NaN   4.0   NaN   3.0   NaN   NaN
# USA                               NaN   3.0   3.0   4.0   6.0   NaN   NaN
#
# year                             2021  2022  2023
# team
# ARGENTINA                         NaN   NaN   NaN
# AUSTRALIA                         NaN   3.0   4.0
# AUSTRIA                           NaN   NaN   NaN
# BELGIUM                           NaN   NaN   NaN
# BRAZIL                            NaN   NaN   NaN
# CANADA                            NaN   3.0   3.0
# CROATIA                           3.0   3.0   NaN
# CZECHIA                           NaN   NaN   2.0
# FINLAND                           NaN   NaN   4.0
# FRANCE                            NaN   NaN   NaN
# GERMANY                           4.0   3.0   NaN
# GREAT BRITAIN                     3.0   NaN   2.0
# HUNGARY                           NaN   NaN   NaN
# ISRAEL                            NaN   NaN   NaN
# ITALY                             3.0   4.0   3.0
# JAPAN                             NaN   NaN   NaN
# KAZAKHSTAN                        3.0   NaN   NaN
# NETHERLANDS                       NaN   NaN   2.0
# POLAND                            NaN   NaN   NaN
# RUSSIA                            NaN   NaN   NaN
# RUSSIAN TENNIS FEDERATION (RTF)   3.0   NaN   NaN
# SERBIA                            4.0   NaN   2.0
# SPAIN                             NaN   2.0   NaN
# SWEDEN                            2.0   NaN   NaN
# SWITZERLAND                       NaN   NaN   NaN
# USA                               NaN   3.0   NaN

# %%
# Highlight values greater than 5
def highlight(value):
    if pd.notnull(value) and value > 5:
        return 'background-color: yellow'
    return ''

styled_table = pivot_table.style.applymap(lambda x: highlight(x))

# Display the styled table
styled_table
# Out:
# C:\Users\aldi\AppData\Local\Temp\ipykernel_37052\1564758840.py:7: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_table = pivot_table.style.applymap(lambda x: highlight(x))
# <style type="text/css">
# #T_c60f2_row0_col2, #T_c60f2_row9_col2, #T_c60f2_row9_col3, #T_c60f2_row9_col4, #T_c60f2_row10_col0, #T_c60f2_row21_col3, #T_c60f2_row22_col4, #T_c60f2_row25_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_c60f2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_c60f2_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_c60f2_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_c60f2_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_c60f2_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_c60f2_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_c60f2_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_c60f2_level0_col6" class="col_heading level0 col6" >2020</th>
#       <th id="T_c60f2_level0_col7" class="col_heading level0 col7" >2021</th>
#       <th id="T_c60f2_level0_col8" class="col_heading level0 col8" >2022</th>
#       <th id="T_c60f2_level0_col9" class="col_heading level0 col9" >2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >team</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c60f2_level0_row0" class="row_heading level0 row0" >ARGENTINA</th>
#       <td id="T_c60f2_row0_col0" class="data row0 col0" >3.000000</td>
#       <td id="T_c60f2_row0_col1" class="data row0 col1" >4.000000</td>
#       <td id="T_c60f2_row0_col2" class="data row0 col2" >7.000000</td>
#       <td id="T_c60f2_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_c60f2_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_c60f2_row0_col5" class="data row0 col5" >3.000000</td>
#       <td id="T_c60f2_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_c60f2_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_c60f2_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_c60f2_row0_col9" class="data row0 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row1" class="row_heading level0 row1" >AUSTRALIA</th>
#       <td id="T_c60f2_row1_col0" class="data row1 col0" >4.000000</td>
#       <td id="T_c60f2_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_c60f2_row1_col2" class="data row1 col2" >3.000000</td>
#       <td id="T_c60f2_row1_col3" class="data row1 col3" >5.000000</td>
#       <td id="T_c60f2_row1_col4" class="data row1 col4" >3.000000</td>
#       <td id="T_c60f2_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_c60f2_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_c60f2_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_c60f2_row1_col8" class="data row1 col8" >3.000000</td>
#       <td id="T_c60f2_row1_col9" class="data row1 col9" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row2" class="row_heading level0 row2" >AUSTRIA</th>
#       <td id="T_c60f2_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_c60f2_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_c60f2_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_c60f2_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_c60f2_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_c60f2_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_c60f2_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_c60f2_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_c60f2_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_c60f2_row2_col9" class="data row2 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row3" class="row_heading level0 row3" >BELGIUM</th>
#       <td id="T_c60f2_row3_col0" class="data row3 col0" >2.000000</td>
#       <td id="T_c60f2_row3_col1" class="data row3 col1" >3.000000</td>
#       <td id="T_c60f2_row3_col2" class="data row3 col2" >3.000000</td>
#       <td id="T_c60f2_row3_col3" class="data row3 col3" >5.000000</td>
#       <td id="T_c60f2_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_c60f2_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_c60f2_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_c60f2_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_c60f2_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_c60f2_row3_col9" class="data row3 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row4" class="row_heading level0 row4" >BRAZIL</th>
#       <td id="T_c60f2_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_c60f2_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_c60f2_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_c60f2_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_c60f2_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_c60f2_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_c60f2_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_c60f2_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_c60f2_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_c60f2_row4_col9" class="data row4 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row5" class="row_heading level0 row5" >CANADA</th>
#       <td id="T_c60f2_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_c60f2_row5_col1" class="data row5 col1" >3.000000</td>
#       <td id="T_c60f2_row5_col2" class="data row5 col2" >3.000000</td>
#       <td id="T_c60f2_row5_col3" class="data row5 col3" >3.000000</td>
#       <td id="T_c60f2_row5_col4" class="data row5 col4" >3.000000</td>
#       <td id="T_c60f2_row5_col5" class="data row5 col5" >3.000000</td>
#       <td id="T_c60f2_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_c60f2_row5_col7" class="data row5 col7" >nan</td>
#       <td id="T_c60f2_row5_col8" class="data row5 col8" >3.000000</td>
#       <td id="T_c60f2_row5_col9" class="data row5 col9" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row6" class="row_heading level0 row6" >CROATIA</th>
#       <td id="T_c60f2_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_c60f2_row6_col1" class="data row6 col1" >4.000000</td>
#       <td id="T_c60f2_row6_col2" class="data row6 col2" >5.000000</td>
#       <td id="T_c60f2_row6_col3" class="data row6 col3" >4.000000</td>
#       <td id="T_c60f2_row6_col4" class="data row6 col4" >4.000000</td>
#       <td id="T_c60f2_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_c60f2_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_c60f2_row6_col7" class="data row6 col7" >3.000000</td>
#       <td id="T_c60f2_row6_col8" class="data row6 col8" >3.000000</td>
#       <td id="T_c60f2_row6_col9" class="data row6 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row7" class="row_heading level0 row7" >CZECHIA</th>
#       <td id="T_c60f2_row7_col0" class="data row7 col0" >4.000000</td>
#       <td id="T_c60f2_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_c60f2_row7_col2" class="data row7 col2" >2.000000</td>
#       <td id="T_c60f2_row7_col3" class="data row7 col3" >2.000000</td>
#       <td id="T_c60f2_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_c60f2_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_c60f2_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_c60f2_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_c60f2_row7_col8" class="data row7 col8" >nan</td>
#       <td id="T_c60f2_row7_col9" class="data row7 col9" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c60f2_level0_row8" class="row_heading level0 row8" >FINLAND</th>
#       <td id="T_c60f2_row8_col0" class="data r

# %%
filtered_df = df[(df['year'] == 2018) & (df['team'] == 'FRANCE')]

unique_players_team = filtered_df['player1'].unique()

# Display the unique players for 2018 and France
print(unique_players_team)
# Out:
# ['Adrian Mannarino' 'Richard Gasquet' 'Pierre-Hugues Herbert'
#  'Lucas Pouille' 'Jeremy Chardy' 'Benoit Paire' 'Julien Benneteau'
#  'Nicolas Mahut' 'Jo-Wilfried Tsonga']
