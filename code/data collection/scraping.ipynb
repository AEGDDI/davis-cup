# %% [markdown]
# # Libraries

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
import time
from selenium.common.exceptions import TimeoutException
import pandas as pd
import glob
from getpass import getuser
import os

# %%
# Get the current user's name
user = getuser()

# %% [markdown]
# # import external functions

# %%
# %run scraping_functions.ipynb

# %% [markdown]
# # Input Directories

# %%
# Path to the ChromeDriver
chrome_driver_path = f"C:/Users/{user}/Downloads/chromedriver.exe"
# Define the directory where the files should be saved
save_directory = f"C:/Users/{user}/Documents/GitHub/davis-cup/data/davis matches/"
# Define the directory where the 'davis_{year}.xlsx' files are saved
directory = f"C:/Users/{user}/Documents/GitHub/davis-cup/data/davis matches/"

# %% [markdown]
# # Retrieve all years links till 2018

# %%
# webpage to scrape
url = "https://www.daviscup.com/en/draws-results/historic-format/world-group.aspx"


# Initialize the WebDriver
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)
driver.get(url)
driver.maximize_window()
wait = WebDriverWait(driver, 15)

# Click on Accept All Cookies button
acceptCookie_Btn = wait.until(EC.element_to_be_clickable((By.ID, "onetrust-accept-btn-handler")))
driver.execute_script("arguments[0].click();", acceptCookie_Btn)

# Initialize an empty DataFrame to store all the data
final_df = pd.DataFrame()

# Loop through selected years
for year in range(2013,2019): 
    # Click on the dropdown arrow
    wait.until(EC.element_to_be_clickable((By.XPATH, "//div[@class='selected']//div[@class='arrow']"))).click()
    time.sleep(4)  # Introduce a delay before clicking the element
    year_xpath = f"//a[text()='{year}']"
    print(year_xpath)
    
    try:
        # Locate the element for the specific year and click it
        year_element = wait.until(EC.presence_of_element_located((By.XPATH, year_xpath)))
        print(year_element)        
        # Click on the element
        year_element.click()
        
        # Wait for the page to load
        driver.implicitly_wait(10)  # You can adjust the waiting time as needed
        time.sleep(10)

        # Find all links with class "tie-link" within the tables
        tie_links = driver.find_elements(By.CSS_SELECTOR, "table.tie.ng-scope a.tie-link")

        # Initialize a list to store the extracted links
        links = []

        # Extract the links
        for link in tie_links:
            href = link.get_attribute("href")
            links.append(href)

        # Call the function to scrape and transform the data
        matches_df, players_df = to_df(links)
        # Cleaning DataFrames
        cleaned_matches_df = clean_matches_df(matches_df)
        cleaned_players_df = clean_players_df(players_df)

        # Merging DataFrames
        merged_df = merge_data_frames(cleaned_matches_df, cleaned_players_df)
        # Add a column with the respective year information
        merged_df['year'] = year

        # Append data to the final DataFrame
        final_df = pd.concat([final_df, merged_df], ignore_index=True)
        
        # Save the current year's data to a separate Excel file in the specified directory
        year_file_name = f"{save_directory}davis_{year}.xlsx"
        merged_df.to_excel(year_file_name, index=False)

    except TimeoutException:
        print(f"TimeoutException occurred while locating element for year {year}. Skipping...")
        continue  # Skip to the next iteration if element not found within the timeout
# Out:
# //a[text()='2013']
# <selenium.webdriver.remote.webelement.WebElement (session="4546d096440948196ff8840786440e4e", element="f.93236DE5E9AA0F71E855F58ABA54CDB2.d.D4ABC8160F8B9B63176CD752D70F5A49.e.1579")>
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-NED-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# [ERROR] Exception occurred: Message: no such element: Unable to locate element: {"method":"css selector","selector":".component-title"}
#   (Session info: chrome=128.0.6613.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF60B30B632+29090]
# 	(No symbol) [0x00007FF60B27E6E9]
# 	(No symbol) [0x00007FF60B13B1CA]
# 	(No symbol) [0x00007FF60B18EFD7]
# 	(No symbol) [0x00007FF60B18F22C]
# 	(No symbol) [0x00007FF60B1827CC]
# 	(No symbol) [0x00007FF60B1B672F]
# 	(No symbol) [0x00007FF60B1826A6]
# 	(No symbol) [0x00007FF60B1B6900]
# 	(No symbol) [0x00007FF60B1D65D9]
# 	(No symbol) [0x00007FF60B1B6493]
# 	(No symbol) [0x00007FF60B1809B1]
# 	(No symbol) [0x00007FF60B181B11]
# 	GetHandleVerifier [0x00007FF60B62881D+3294093]
# 	GetHandleVerifier [0x00007FF60B674403+3604339]
# 	GetHandleVerifier [0x00007FF60B66A2C7+3563063]
# 	GetHandleVerifier [0x00007FF60B3C6F16+797318]
# 	(No symbol) [0x00007FF60B28986F]
# 	(No symbol) [0x00007FF60B285454]
# 	(No symbol) [0x00007FF60B2855E0]
# 	(No symbol) [0x00007FF60B274A7F]
# 	BaseThreadInitThunk [0x00007FFEFEB57374+20]
# 	RtlUserThreadStart [0x00007FFF00B5CC91+33]
#
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-ITA-JPN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-GBR-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-AUS-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-KAZ-SUI-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-CAN-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-USA-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-HUN-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-ITA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-ESP-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-KAZ-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-USA-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-CRO-USA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 122
# Total number of rows in players_df: 175
# //a[text()='2014']
# <selenium.webdriver.remote.webelement.WebElement (session="4546d096440948196ff8840786440e4e", element="f.93236DE5E9AA0F71E855F58ABA54CDB2.d.D4ABC8160F8B9B63176CD752D70F5A49.e.4499")>
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-CZE-NED-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-CAN-JPN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-ESP-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 4
# Skipping match 4
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-FRA-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-GBR-USA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-ITA-ARG-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-BEL-KAZ-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-SUI-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-CZE-JPN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-GER-FRA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-GBR-ITA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-KAZ-SUI-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-CZE-FRA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-ITA-SUI-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2014-WG-M-FRA-SUI-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 142
# Total number of rows in players_df: 149
# //a[text()='2015']
# <selenium.webdriver.remote.webelement.WebElement (session="4546d096440948196ff8840786440e4e", element="f.93236DE5E9AA0F71E855F58ABA54CDB2.d.D4ABC8160F8B9B63176CD752D70F5A49.e.6565")>
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-FRA-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# [ERROR] Exception occurred: No objects to concatenate
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-USA-GBR-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-CZE-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-ITA-KAZ-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# [ERROR] Exception occurred: No objects to concatenate
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-BRA-ARG-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-CRO-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-JPN-CAN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-BEL-SUI-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-FRA-GBR-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# [ERROR] Exception occurred: No objects to concatenate
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-AUS-KAZ-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-ARG-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-CAN-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# [ERROR] Exception occurred: "None of [Index(['team_name'], dtype='object')] are in the [columns]"
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-GBR-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-ARG-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2015-WG-M-GBR-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 118
# Total number of rows in players_df: 140
# //a[text()='2016']
# <selenium.webdriver.remote.webelement.WebElement (session="4546d096440948196ff8840786440e4e", element="f.93236DE5E9AA0F71E855F58ABA54CDB2.d.D4ABC8160F8B9B63176CD752D70F5A49.e.8631")>
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-GBR-JPN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-SRB-KAZ-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-SUI-ITA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-ARG-POL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-CAN-FRA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-GER-CZE-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-USA-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-CRO-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-GBR-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-ITA-ARG-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-FRA-CZE-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# [ERROR] Exception occurred: No objects to concatenate
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-USA-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-GBR-ARG-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-FRA-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2016-WG-M-ARG-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 134
# Total number of rows in players_df: 150
# //a[text()='2017']
# <selenium.webdriver.remote.webelement.WebElement (session="4546d096440948196ff8840786440e4e", element="f.93236DE5E9AA0F71E855F58ABA54CDB2.d.D4ABC8160F8B9B63176CD752D70F5A49.e.10708")>
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-ARG-ITA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-BEL-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-CZE-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-SUI-USA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-JPN-FRA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-CAN-GBR-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-RUS-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-ESP-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-ITA-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-AUS-USA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-FRA-GBR-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-SRB-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-BEL-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-FRA-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2017-WG-M-BEL-FRA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# [ERROR] Exception occurred: No objects to concatenate
# players df downloaded
# Total number of rows in matches_df: 138
# Total number of rows in players_df: 150
# //a[text()='2018']
# <selenium.webdriver.remote.webelement.WebElement (session="4546d096440948196ff8840786440e4e", element="f.93236DE5E9AA0F71E855F58ABA54CDB2.d.D4ABC8160F8B9B63176CD752D70F5A49.e.12779")>
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-NED-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-ITA-JPN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-GBR-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-AUS-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-KAZ-SUI-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-CAN-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-USA-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-HUN-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-ITA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-ESP-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-KAZ-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-USA-BEL-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-CRO-USA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2018-WG-M-FRA-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 5
# Skipping match 5
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 130
# Total number of rows in players_df: 175

# %% [markdown]
# In a year I have 15 matches (number of link), each match has a max number of 5 matches and on avg 4 matches. The number of single matches should be therefore between 60 and 70. We have two observations (one for each player or team) for each match for a total of 120/140 rows (max 75*2 = 150).
#
# We have 5 players in each team, two team in each match, and 15 matches for a total of (5 * 2 * 15) 150 players/teams.
#
# players of teams advancing to the next stage appear more than ones with the same information. it would be efficient to not repeat the data collection for those observations.

# %% [markdown]
# # Retrieve all years links from 2019

# %%
# webpage to scrape
url = ("https://www.daviscup.com/en/draws-results/finals/2019.aspx")
# Initialize the WebDriver
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service)
driver.get(url)
driver.maximize_window()
wait = WebDriverWait(driver, 15)

# Initialize an empty DataFrame to store all the data
final_df = pd.DataFrame()

# Loop through selected years (2019 to 2023)
for year in range(2019, 2024):  # Change the range accordingly
    current_url = f"https://www.daviscup.com/en/draws-results/finals/{year}.aspx"
    
    try:
        driver.get(current_url)
        # Wait for the page to load
        driver.implicitly_wait(10)  # You can adjust the waiting time as needed
        time.sleep(10)

        # Find all links with class "tie-link" within the tables
        tie_links = driver.find_elements(By.CSS_SELECTOR, "table.tie.ng-scope a.tie-link")
        
        # Initialize a list to store the extracted links
        links = []

        # Extract the links
        for link in tie_links:
            href = link.get_attribute("href")
            links.append(href)

        # Call the function to scrape and transform the data
        matches_df, players_df = to_df(links)
        # Cleaning DataFrames
        cleaned_matches_df = clean_matches_df(matches_df)
        cleaned_players_df = clean_players_df(players_df)

        # Merging DataFrames
        merged_df = merge_data_frames(cleaned_matches_df, cleaned_players_df)
        # Add a column with the respective year information
        merged_df['year'] = year

        # Append data to the final DataFrame
        final_df = pd.concat([final_df, merged_df], ignore_index=True)
        # Save the current year's data to a separate Excel file in the specified directory
        year_file_name = f"{save_directory}davis_{year}.xlsx"
        final_df.to_excel(year_file_name, index=False)

    except TimeoutException:
        print(f"TimeoutException occurred while processing year {year}. Skipping...")
        continue  # Skip to the next iteration if page not loaded within the timeout

    except Exception as e:
        print(f"An error occurred for year {year}: {str(e)}")
        continue  # Continue to the next iteration if an error occurs

# Close the WebDriver
driver.quit()
# Out:
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2019-FLS-M-SRB-RUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2019-FLS-M-AUS-CAN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2019-FLS-M-GBR-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2019-FLS-M-ARG-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2019-FLS-M-RUS-CAN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2019-FLS-M-GBR-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2019-FLS-M-CAN-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 38
# Total number of rows in players_df: 77
# Total number of rows in matches_df: 0
# Total number of rows in players_df: 0
# An error occurred for year 2020: "None of [Index(['player', 'set1', 'set2', 'set3', 'set4', 'set5', 'tb1', 'tb2', 'tb3',\n       'tb4', 'tb5'],\n      dtype='object')] are in the [columns]"
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2021-FLS-M-RTF-SWE-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2021-FLS-M-GBR-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2021-FLS-M-ITA-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2021-FLS-M-SRB-KAZ-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2021-FLS-M-RTF-GER-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2021-FLS-M-CRO-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2021-FLS-M-RTF-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 38
# Total number of rows in players_df: 84
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2022-FLS-M-ITA-USA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2022-FLS-M-GER-CAN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2022-FLS-M-AUS-NED-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2022-FLS-M-CRO-ESP-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2022-FLS-M-ITA-CAN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2022-FLS-M-AUS-CRO-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2022-FLS-M-CAN-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 36
# Total number of rows in players_df: 83
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2023-FLS-M-CAN-FIN-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2023-FLS-M-CZE-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2023-FLS-M-ITA-NED-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2023-FLS-M-SRB-GBR-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2023-FLS-M-FIN-AUS-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2023-FLS-M-ITA-SRB-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# matches df downloaded
# players df downloaded
# Processing match: https://www.daviscup.com/en/draws-results/tie.aspx?id=M-DC-2023-FLS-M-AUS-ITA-01
# Initializing Selenium...
# Navigating to the webpage...
# Waiting for the page to load...
# Skipping match 3
# Skipping match 3
# matches df downloaded
# players df downloaded
# Total number of rows in matches_df: 36
# Total number of rows in players_df: 83

# %% [markdown]
# In a year I have 7 matches (number of link), each match has a max number of 3 matches. The number of single matches should be 21. We have two observations (one for each player or team) for each match for a total of 42 (21*2) rows.
#
# We have 5 players in each team, two team in each match, and 7 matches for a total of (5 * 2 * 7) 70 players/teams.
# We have on avg 5 player per team and 8 teams competing from the quarter finals, for a total of 40 (8*5) players.
#
# players of teams advancing to the next stage appear more than ones with the same information. it would be efficient to not repeat the data collection for those observations.

# %%
# check if each team has, on average, 5 players

# Group by 'Team Name' and count unique players
unique_players_per_team = cleaned_players_df.groupby('team_name')['player'].nunique()

# Display the counts
print(unique_players_per_team)
# Out:
# team_name
# AUSTRALIA        5
# CANADA           5
# CZECHIA          4
# FINLAND          5
# GREAT BRITAIN    5
# ITALY            5
# NETHERLANDS      5
# SERBIA           5
# Name: player, dtype: int64

# %% [markdown]
# ## concatenate all xlsx in a unique file

# %%
# File path pattern to match all 'davis_{year}.xlsx' files in the specified directory
file_pattern = os.path.join(directory, 'davis_*.xlsx')

# Get a list of all file paths matching the pattern
file_paths = glob.glob(file_pattern)

# Create an empty list to store DataFrame objects
dataframes = []

# Read each Excel file into a DataFrame, standardize column names to lowercase, and append to the list
for file_path in file_paths:
    df = pd.read_excel(file_path)
    
    # Convert all column names to lowercase
    df.columns = df.columns.str.lower()
    
    # Append the DataFrame to the list
    dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the concatenated DataFrame to a new Excel file
combined_df.to_excel(os.path.join(directory, 'combined_davis.xlsx'), index=False)

# Verify the operation
print("All files have been successfully combined and saved to 'combined_davis.xlsx'.")
# Out:
# All files have been successfully combined and saved to 'combined_davis.xlsx'.
